# %% [markdown]
# # Object Detection And Classification For Species Recognition

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Around 12% of current bird species are considered endangered, threatened or vulnerable in some way. Many birds play a crucial roll in ecological systems for both predator and prey. Bird species such as these are known as 'keystone species' that hold an invaluable presence in their respective ecosystems. For example, a lot of birds are host to a variety of parasites and flys that also hold weight within their food chains. Additionally, many birds aid in pollination of certain plant species and creation of subhabitats such as nests or entry points in trees (woodpecker). It is incredibly important to conserve these species for both ecological and humane reasons. Not to mention, birds are peculiar and amusing to us. It would be a shame to go out on a walk and not hear the specific chirping melody based on the regional species.
# What we can do is propose a habitat protection movement. Habitat loss and destruction are one of the leading causes of bird species extinction. We can discretely place cameras in areas we know there may be endangered species and are being considered for deforestation or other means of habitat disruption. We will attempt to train our own bird detection system so that we can appropriately assess the population and activity of specific species within our geographical regions of study. Working with local governments and species conservation groups, we can present our data and work against habitat loss.

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# We used a combination of images from Cal-Tech's bird data set and a basic google image search of certain species. Cal-Tech's bird data set includes 200 species of around 80 images per species. We have abridged the dataset to 3 species of around 60 images per species. The intended outcome of our study is to analyze various methods of segmentation and object detection, as opposed to produced a highly accurate bird classification model (although we will include classification). Image segmentation allows us to extract and separate different regions given to us with boundary box coordinates. We are going to apply two segmentation approaches, a selective search approach and a histogram of oriented gradients approach. We will then apply and evaluate various classification algorithms that will help us determine which segments are of interest (bird) and which are not (background noise, other animals,..so on)

# %% [markdown]
# Selective Search
# - Diverse application of grouping/segmentation algorithms based on color/texture/shape
# - Proposes multiple regions of interest
# - heirarchical
#
# HOG
# - Represents images as a single feature vecture as opposed to a bunch of feature vectors with each vector representing a segment of the image.
# - sliding a window detector over the image.

# %% [markdown]
# As with many image recognition, and object detection problems, we run into many recurrent and expected problems. We have to consider many factors: we see birds with different poses, facing different directions, leaning forwards or backwards, facing the camera or facing away, flying or standing or swimming. We also have to considered different background classes: lighting is different across our set, we have different genres of terrain per species (what region are these species found in), and similary we have to account for seasonality, weather conditions, time of day, etc.. We have accounted for some of these issues with data augmentation where we have generated noise that can be considered synonymous with camera inconsistencies (scratching,dust) and orientation flips (pose left,right). Our augmentation was minimal given time constraints and annotations, we are avoiding rotation.
#
# For both approaches, we fit and evaluated various classification algorithms in a binary setting (foreground,background). We use our annotated boundary boxes on our birds so we can retrieve suggested candidate regions for foreground objects. We calculated an Intersection over Union score (IoU) to determine how overlapped our proposed regions by our segmentation are with our ground truth (annoted labels) box. Regions with a score greater than 0.7 would be classified as foreground and regions with a score less than 0.3 would be classified as background. Scores between 0.7 and 0.3 are ignored. Our classification models include SVC, KNN, and LogisticRegression.

# %% [markdown]
# ## Building a Region-based CNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import cv2

from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression



# import keras
# from keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Flatten,Dense, ZeroPadding2D, Dropout, Input
from keras.preprocessing.image import ImageDataGenerator
from keras.engine.topology import Layer
import keras.backend as K
import keras.layers as KL
import keras.models as KM


import xml.etree.ElementTree as ET
# Out:
# Using TensorFlow backend.
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
train_path='./data/bird2_train/'
test_path='./data/bird2_test/'

# %% [markdown]
# ## Read in CVAT annotion file with XML parser

# %%
def create_df_xml(input1):
    annotation=ET.parse(f'./data/bird2_{input1}/{input1}_annotations.xml')
    root=annotation.getroot()
    df_cols=['root','filename','w','h']
    df_rows=[]
    for node in root.iter('image'):
        #print (list(node.attrib.values()))
        s_root=f'/data/bird2_{input1}/'
        s_name=list(node.attrib.values())[1]
        s_height=list(node.attrib.values())[3]
        s_width=list(node.attrib.values())[2]
         
        
    
        df_rows.append({'root':s_root,'filename': s_name,'w':s_width,'h':s_height,
                            })
        x1=pd.DataFrame(df_rows, columns = df_cols)
    df_cols=['x1','x2','y1','y2','label']
    df_rows=[]
    for node in root.iter('image'):
        for node1 in node:
            s_x1=list(node1.attrib.values())[2]
            s_x2=list(node1.attrib.values())[4]
            s_y1=list(node1.attrib.values())[3]
            s_y2=list(node1.attrib.values())[5]
            s_label=list(node1.attrib.values())[0]
            df_rows.append({
                            'x1':s_x1,'x2':s_x2,'y1':s_y1,'y2':s_y2,'label':s_label})
        x2=pd.DataFrame(df_rows,columns=df_cols)
    x4= pd.concat((x1,x2),axis=1)  
    annotation=ET.parse(f'./data/bird2_{input1}/{input1}_parts.xml')
    root=annotation.getroot()
    
    
    df_cols=['wing']
    df_rows=[]
    for node in root.iter('image'):
        #s_name=list(node.attrib.values())[1]
        for node1 in node:
            #print(node1.attrib)
            for node2 in node1:
    
                if node2.text=='wing':
                    s_wing=node1.attrib
                    
                #print(node2.text)
                #print('hi')
                    df_rows.append({
                                'wing':s_wing})
            x1=pd.DataFrame(df_rows,columns=df_cols)
    
    df_cols=['head']
    df_rows=[]
    for node in root.iter('image'):
        #s_name=list(node.attrib.values())[1]
        for node1 in node:
            #print(node1.attrib)
            for node2 in node1:
    
                if node2.text=='head':
                    s_head=node1.attrib
                    
                #print(node2.text)
                #print('hi')
                    df_rows.append({
                                'head':s_head})
            x2=pd.DataFrame(df_rows,columns=df_cols)
    x3=pd.concat((x1,x2),axis=1)
    return pd.concat((x4,x3),axis=1)

# %%
test1=create_df_xml('test')
train1=create_df_xml('train')

# %%
train1
# Out:
#                   root                                filename    w    h  \
# 0   /data/bird2_train/                      70095201-480px.jpg  480  360
# 1   /data/bird2_train/      Black_Footed_Albatross_0002_55.jpg  500  347
# 2   /data/bird2_train/  Black_Footed_Albatross_0042_796071.jpg  500  356
# 3   /data/bird2_train/  Black_Footed_Albatross_0051_796103.jpg  500  391
# 4   /data/bird2_train/  Black_Footed_Albatross_0056_796078.jpg  500  390
# 5   /data/bird2_train/  Black_Footed_Albatross_0060_796076.jpg  320  240
# 6   /data/bird2_train/  Black_Footed_Albatross_0061_796082.jpg  240  187
# 7   /data/bird2_train/     Black_Footed_Albatross_0076_417.jpg  500  441
# 8   /data/bird2_train/     Black_Footed_Albatross_0081_426.jpg  500  320
# 9   /data/bird2_train/                 Cardinal_0051_17223.jpg  500  421
# 10  /data/bird2_train/                 Cardinal_0052_18334.jpg  500  330
# 11  /data/bird2_train/                 Cardinal_0053_17541.jpg  377  500
# 12  /data/bird2_train/                 Cardinal_0054_19334.jpg  435  500
# 13  /data/bird2_train/                 Cardinal_0055_18898.jpg  500  333
# 14  /data/bird2_train/                 Cardinal_0056_18352.jpg  500  375
# 15  /data/bird2_train/                 Cardinal_0075_17946.jpg  399  500
# 16  /data/bird2_train/                 Cardinal_0078_17181.jpg  500  477
# 17  /data/bird2_train/                 Cardinal_0079_19044.jpg  500  346
# 18  /data/bird2_train/                 Cardinal_0081_17291.jpg  500  341
# 19  /data/bird2_train/                 Cardinal_0085_19162.jpg  500  334
# 20  /data/bird2_train/                 Cardinal_0089_18005.jpg  500  353
# 21  /data/bird2_train/                 Cardinal_0092_17591.jpg  500  500
# 22  /data/bird2_train/                 Cardinal_0093_17676.jpg  407  500
# 23  /data/bird2_train/       Western_Meadowlark_0040_77823.jpg  500  400
# 24  /data/bird2_train/       Western_Meadowlark_0042_78180.jpg  500  336
# 25  /data/bird2_train/       Western_Meadowlark_0048_78354.jpg  332  500
# 26  /data/bird2_train/       Western_Meadowlark_0081_77798.jpg  433  500
# 27  /data/bird2_train/       Western_Meadowlark_0083_78197.jpg  499  500
# 28  /data/bird2_train/       Western_Meadowlark_0085_77745.jpg  500  377
# 29  /data/bird2_train/       Western_Meadowlark_0086_78636.jpg  309  432
# 30  /data/bird2_train/       Western_Meadowlark_0091_78576.jpg  500  386
# 31  /data/bird2_train/       Western_Meadowlark_0108_78155.jpg  500  375
# 32  /data/bird2_train/       Western_Meadowlark_0109_77990.jpg  353  500
# 33  /data/bird2_train/       Western_Meadowlark_0112_78760.jpg  500  400
# 34  /data/bird2_train/       Western_Meadowlark_0115_77882.jpg  500  439
# 35  /data/bird2_train/       Western_Meadowlark_0116_77862.jpg  500  476
# 36  /data/bird2_train/       Western_Meadowlark_0120_77834.jpg  500  333
# 37  /data/bird2_train/            albatros-pieds-noirs-tg3.jpg  500  350
# 38  /data/bird2_train/                   bfa_water_rsuryan.jpg  450  290
# 39  /data/bird2_train/              black_footed_albatross.jpg  610  473
# 40  /data/bird2_train/             black_footed_albatross1.jpg  640  456
# 41  /data/bird2_train/             black_footed_albatross2.jpg  259  194
#
#         x1      x2      y1      y2               label  \
# 0     6.72  422.55   67.11  308.78                 BFA
# 1    12.04  403.98  109.90  298.88                 BFA
# 2   134.72  442.23   82.85  261.11                 BFA
# 3    79.58  411.60   88.58  238.16                 BFA
# 4   147.48  345.61   88.37  259.90                 BFA
# 5    10.94  292.23   77.78  211.41                 BFA
# 6    50.09  209.12   24.83  162.21                 BFA
# 7    74.39  425.77  115.49  324.50                 BFA
# 8    94.13  357.29   75.26  249.53                 BFA
# 9    10.56  188.54  191.31  407.76            Cardinal
# 10   32.58  395.63   87.62  259.30            Cardinal
# 11   60.70  281.22   85.92  448.37            Cardinal
# 12   64.11  386.97   73.12  442.89            Cardinal
# 13  293.48  438.32   77.08  326.99            Cardinal
# 14   94.90  441.48    0.00  292.51            Cardinal
# 15   91.22  272.14  107.85  320.44            Cardinal
# 16  131.75  445.64   28.26  425.07            Cardinal
# 17  234.90  417.43   53.13  215.84            Cardinal
# 18   90.11  378.89   77.69  308.68            Cardinal
# 19  116.17  469.50   18.54  313.23            Cardinal
# 20  162.35  286.21   75.26  298.47            Cardinal
# 21   87.33  427.24   45.81  455.90            Cardinal
# 22  136.01  356.78   18.18  498.44            Cardinal
# 23  119.32  456.17   62.69  276.02  Western_Meadowlark
# 24  261.26  392.71   74.93  263.56  Western_Meadowlark
# 25   36.82  246.61  107.73  439.60  Western_Meadowlark
# 26   78.34  410.94   93.32  447.86  Western_Meadowlark
# 27   86.79  485.74   48.27  465.11  Western_Meadowlark
# 28  256.09  418.14   68.58  300.08  Western_Meadowlark
# 29   79.16  244.78   83.53  385.47  Western_Meadowlark
# 30   61.13  388.44   87.49  275.41  Western_Meadowlark
# 31   35.36  299.43  113.76  270.46  Western_Meadowlark
# 32  110.83  264.95  144.40  379.53  Western_Meadowlark
# 33  122.69  397.08    6.97  325.50  Western_Meadowlark
# 34  167.01  367.56   62.94  317.10  Western_Meadowlark
# 35  145.67  301.15  184.99  335.19  Western_Meadowlark
# 36  185.16  359.20  120.89  264.11  Western_Meadowlark
# 37  106.87  466.08   52.58  226.36                 BFA
# 38   56.16  380.89   84.42  257.90                 BFA
# 39  164.38  557.16   43.09  397.84                 BFA
# 40   83.39  456.23   97.23  284.45                 BFA
# 41   54.63  256.72   25.30  161.44                 BFA
#
#                                                  wing  \
# 0   {'label': 'BFA', 'occluded': '0', 'xtl': '75.6...
# 1   {'label': 'BFA', 'occluded': '0', 'xtl': '42.1...
# 2   {'label': 'BFA', 'occluded': '0', 'xtl': '210....
# 3   {'label': 'BFA', 'occluded': '0', 'xtl': '182....
# 4   {'label': 'BFA', 'occluded': '0', 'xtl': '194....
# 5   {'label': 'BFA', 'occluded': '0', 'xtl': '50.7...
# 6   {'label': 'BFA', 'occluded': '0', 'xtl': '80.4...
# 7   {'label': 'BFA', 'occluded': '0', 'xtl': '108....
# 8   {'label': 'BFA', 'occluded': '0', 'xtl': '106....
# 9   {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 10  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 11  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 12  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 13  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 14  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 15  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 16  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 17  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 18  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 19  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 20  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 21  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 22  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 23  {'label': 'Western_Meadowlark', 'occluded': '0...
# 24  {'label': 'Western_Meadowlark', 'occluded': '0...
# 25  {'label': 'Western_Meadowlark', 'occluded': '0...
# 26  {'label': 'Western_Meadowlark', 'occluded': '0...
# 27  {'label': 'Western_Meadowlark', 'occluded': '0...
# 28  {'label': 'Western_Meadowlark', 'occluded': '0...
# 29  {'label': 'Western_Meadowlark', 'occluded': '0...
# 30  {'label': 'Western_Meadowlark', 'occluded': '0...
# 31  {'label': 'Western_Meadowlark', 'occluded': '0...
# 32  {'label': 'Western_Meadowlark', 'occluded': '0...
# 33  {'label': 'Western_Meadowlark', 'occluded': '0...
# 34  {'label': 'Western_Meadowlark', 'occluded': '0...
# 35  {'label': 'Western_Meadowlark', 'occluded': '0...
# 36  {'label': 'Western_Meadowlark', 'occluded': '0...
# 37  {'label': 'BFA', 'occluded': '0', 'xtl': '184....
# 38  {'label': 'BFA', 'occluded': '0', 'xtl': '106....
# 39  {'label': 'BFA', 'occluded': '0', 'xtl': '332....
# 40  {'label': 'BFA', 'occluded': '0', 'xtl': '141....
# 41  {'label': 'BFA', 'occluded': '0', 'xtl': '93.6...
#
#                                                  head
# 0   {'label': 'BFA', 'occluded': '0', 'xtl': '252....
# 1   {'label': 'BFA', 'occluded': '0', 'xtl': '277....
# 2   {'label': 'BFA', 'occluded': '0', 'xtl': '175....
# 3   {'label': 'BFA', 'occluded': '0', 'xtl': '114....
# 4   {'label': 'BFA', 'occluded': '0', 'xtl': '287....
# 5   {'label': 'BFA', 'occluded': '0', 'xtl': '189....
# 6   {'label': 'BFA', 'occluded': '0', 'xtl': '78.5...
# 7   {'label': 'BFA', 'occluded': '0', 'xtl': '302....
# 8   {'label': 'BFA', 'occluded': '0', 'xtl': '248....
# 9   {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 10  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 11  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 12  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 13  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 14  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 15  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 16  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 17  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 18  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 19  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 20  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 21  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 22  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 23  {'label': 'Western_Meadowlark', 'occluded': '0...
# 24  {'label': 'Western_Meadowlark', 'occluded': '0...
# 25  {'label': 'Western_Meadowlark', 'occluded': '0...
# 26  {'label': 'Western_Meadowlark', 'occluded': '0...
# 27  {'label': 'Western_Meadowlark', 'occluded': '0...
# 28  {'label': 'Western_Meadowlark', 'occluded': '0...
# 29  {'label': 'Western_Meadowlark', 'occluded': '0...
# 30  {'label': 'Western_Meadowlark', 'occluded': '0...
# 31  {'label': 'Western_Meadowlark', 'occluded': '0...
# 32  {'label': 'Western_Meadowlark', 'occluded': '0...
# 33  {'label': 'Western_Meadowlark', 'occluded': '0...
# 34  {'label': 'Western_Meadowlark', 'occluded': '0...
# 35  {'label': 'Western_Meadowlark', 'occluded': '0...
# 36  {'label': 'Western_Meadowlark', 'occluded': '0...
# 37  {'label': 'BFA', 'occluded': '0', 'xtl': '130....
# 38  {'label': 'BFA', 'occluded': '0', 'xtl': '266....
# 39  {'label': 'BFA', 'occluded': '0', 'xtl': '222....
# 40  {'label': 'BFA', 'occluded': '0', 'xtl': '344....
# 41  {'label': 'BFA', 'occluded': '0', 'xtl': '86.5...

# %%
train1['wing'][1]
# Out:
# {'label': 'BFA',
#  'occluded': '0',
#  'xtl': '42.11',
#  'ytl': '188.60',
#  'xbr': '279.70',
#  'ybr': '269.31'}

# %%
test1
# Out:
#                  root                                filename    w    h  \
# 0   /data/bird2_test/  Black_Footed_Albatross_0033_796086.jpg  500  375
# 1   /data/bird2_test/     Black_Footed_Albatross_0038_212.jpg  500  332
# 2   /data/bird2_test/  Black_Footed_Albatross_0039_796132.jpg  500  500
# 3   /data/bird2_test/  Black_Footed_Albatross_0057_796106.jpg  500  337
# 4   /data/bird2_test/  Black_Footed_Albatross_0063_796141.jpg  288  192
# 5   /data/bird2_test/  Black_Footed_Albatross_0069_796139.jpg  200  200
# 6   /data/bird2_test/  Black_Footed_Albatross_0090_796077.jpg  216  136
# 7   /data/bird2_test/                 Cardinal_0002_18424.jpg  333  500
# 8   /data/bird2_test/                 Cardinal_0006_17684.jpg  500  427
# 9   /data/bird2_test/                 Cardinal_0033_19215.jpg  401  500
# 10  /data/bird2_test/                 Cardinal_0040_17477.jpg  500  338
# 11  /data/bird2_test/                 Cardinal_0057_17128.jpg  500  393
# 12  /data/bird2_test/                 Cardinal_0060_17139.jpg  420  500
# 13  /data/bird2_test/                 Cardinal_0083_18042.jpg  500  375
# 14  /data/bird2_test/                 Cardinal_0084_17576.jpg  500  409
# 15  /data/bird2_test/                 Cardinal_0104_17122.jpg  352  500
# 16  /data/bird2_test/       Western_Meadowlark_0044_77758.jpg  357  500
# 17  /data/bird2_test/       Western_Meadowlark_0050_77864.jpg  500  400
# 18  /data/bird2_test/       Western_Meadowlark_0053_77774.jpg  429  500
# 19  /data/bird2_test/       Western_Meadowlark_0076_77811.jpg  500  366
# 20  /data/bird2_test/       Western_Meadowlark_0077_77814.jpg  500  354
# 21  /data/bird2_test/       Western_Meadowlark_0095_78568.jpg  380  295
# 22  /data/bird2_test/       Western_Meadowlark_0103_78500.jpg  500  344
# 23  /data/bird2_test/       Western_Meadowlark_0104_78105.jpg  500  468
# 24  /data/bird2_test/       Western_Meadowlark_0107_78608.jpg  384  500
#
#         x1      x2      y1      y2               label  \
# 0    36.18  440.24   62.17  238.15                 BFA
# 1   134.41  429.68   61.48  223.27                 BFA
# 2   150.79  460.31  151.71  354.56                 BFA
# 3    69.41  362.56   40.22  266.45                 BFA
# 4    47.44  243.70   26.67  140.82                 BFA
# 5     7.46  192.89   46.05  165.45                 BFA
# 6     6.12  215.61    3.75  134.03                 BFA
# 7   107.29  269.57   63.72  458.46            Cardinal
# 8   162.68  489.38   97.81  391.21            Cardinal
# 9    99.57  316.23   58.95  479.13            Cardinal
# 10  117.89  384.32   91.00  240.48            Cardinal
# 11   20.62  441.96   27.93  293.37            Cardinal
# 12   91.34  372.77  112.11  453.24            Cardinal
# 13   86.98  474.41   74.01  324.83            Cardinal
# 14   57.77  301.44  160.97  333.38            Cardinal
# 15   35.87  316.57   49.10  478.19            Cardinal
# 16   50.04  249.29   96.88  310.09  Western_Meadowlark
# 17   69.27  389.94  107.68  282.14  Western_Meadowlark
# 18   24.51  274.94   51.20  260.75  Western_Meadowlark
# 19   85.51  300.04   95.86  319.26  Western_Meadowlark
# 20  125.83  313.92   60.79  296.28  Western_Meadowlark
# 21   57.09  373.72   25.17  201.28  Western_Meadowlark
# 22   71.53  223.25  139.55  244.33  Western_Meadowlark
# 23  153.73  446.80  110.62  387.73  Western_Meadowlark
# 24  108.03  310.27   90.18  332.02  Western_Meadowlark
#
#                                                  wing  \
# 0   {'label': 'BFA', 'occluded': '0', 'xtl': '177....
# 1   {'label': 'BFA', 'occluded': '0', 'xtl': '241....
# 2   {'label': 'BFA', 'occluded': '0', 'xtl': '210....
# 3   {'label': 'BFA', 'occluded': '0', 'xtl': '118....
# 4   {'label': 'BFA', 'occluded': '0', 'xtl': '115....
# 5   {'label': 'BFA', 'occluded': '0', 'xtl': '28.6...
# 6   {'label': 'BFA', 'occluded': '0', 'xtl': '84.9...
# 7   {'label': 'BFA', 'occluded': '0', 'xtl': '115....
# 8   {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 9   {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 10  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 11  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 12  {'label': 'BFA', 'occluded': '0', 'xtl': '167....
# 13  {'label': 'BFA', 'occluded': '0', 'xtl': '207....
# 14  {'label': 'BFA', 'occluded': '0', 'xtl': '133....
# 15  {'label': 'BFA', 'occluded': '0', 'xtl': '108....
# 16  {'label': 'Western_Meadowlark', 'occluded': '0...
# 17  {'label': 'Western_Meadowlark', 'occluded': '0...
# 18  {'label': 'Western_Meadowlark', 'occluded': '0...
# 19  {'label': 'Western_Meadowlark', 'occluded': '0...
# 20  {'label': 'Western_Meadowlark', 'occluded': '0...
# 21  {'label': 'Western_Meadowlark', 'occluded': '0...
# 22  {'label': 'Western_Meadowlark', 'occluded': '0...
# 23  {'label': 'Western_Meadowlark', 'occluded': '0...
# 24  {'label': 'Western_Meadowlark', 'occluded': '0...
#
#                                                  head
# 0   {'label': 'BFA', 'occluded': '0', 'xtl': '75.5...
# 1   {'label': 'BFA', 'occluded': '0', 'xtl': '169....
# 2   {'label': 'BFA', 'occluded': '0', 'xtl': '186....
# 3   {'label': 'BFA', 'occluded': '0', 'xtl': '225....
# 4   {'label': 'BFA', 'occluded': '0', 'xtl': '59.1...
# 5   {'label': 'BFA', 'occluded': '0', 'xtl': '137....
# 6   {'label': 'BFA', 'occluded': '0', 'xtl': '32.0...
# 7   {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 8   {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 9   {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 10  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 11  {'label': 'Cardinal', 'occluded': '0', 'xtl': ...
# 12  {'label': 'BFA', 'occluded': '0', 'xtl': '83.4...
# 13  {'label': 'BFA', 'occluded': '0', 'xtl': '117....
# 14  {'label': 'BFA', 'occluded': '0', 'xtl': '222....
# 15  {'label': 'BFA', 'occluded': '0', 'xtl': '39.6...
# 16  {'label': 'Western_Meadowlark', 'occluded': '0...
# 17  {'label': 'Western_Meadowlark', 'occluded': '0...
# 18  {'label': 'Western_Meadowlark', 'occluded': '0...
# 19  {'label': 'Western_Meadowlark', 'occluded': '0...
# 20  {'label': 'Western_Meadowlark', 'occluded': '0...
# 21  {'label': 'Western_Meadowlark', 'occluded': '0...
# 22  {'label': 'Western_Meadowlark', 'occluded': '0...
# 23  {'label': 'Western_Meadowlark', 'occluded': '0...
# 24  {'label': 'Western_Meadowlark', 'occluded': '0...

# %%
train1['w']=train1['w'].astype(int)
train1['h']=train1['h'].astype(int)
train1['x1']=train1['x1'].astype(float).round().astype(int)
train1['x2']=train1['x2'].astype(float).round().astype(int)
train1['y1']=train1['y1'].astype(float).round().astype(int)
train1['y2']=train1['y2'].astype(float).round().astype(int)

# %%
test1['w']=test1['w'].astype(int)
test1['h']=test1['h'].astype(int)
test1['x1']=test1['x1'].astype(float).round().astype(int)
test1['x2']=test1['x2'].astype(float).round().astype(int)
test1['y1']=test1['y1'].astype(float).round().astype(int)
test1['y2']=test1['y2'].astype(float).round().astype(int)

# %% [markdown]
# ## Ground truth boxes

# %%
def bbox_plot(index):

    image = cv2.imread('.'+test1['root'][index]+test1['filename'][index])
    image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    x1=test1['x1'][index]
    x2=test1['x2'][index]
    y1=test1['y1'][index]
    y2=test1['y2'][index]

    fig,ax = plt.subplots(1)
    ax.imshow(image)
    rect = patches.Rectangle((x1,y1),x2-x1,y2-y1,linewidth=3,edgecolor=np.random.rand(3,),facecolor='none')
    ##(x1,y1),x2-x1,y2-y1
    ax.add_patch(rect)
    print(x1,x2,y1,y2)
    return plt.imshow(image)

# %%
bbox_plot(5)
# Out:
# 7 193 46 165

# %%
bbox_plot(13)
# Out:
# 87 474 74 325

# %% [markdown]
# ## Initial configurations

# %% [markdown]
# ## Region Proposal System

# %%
#https://towardsdatascience.com/region-proposal-network-a-detailed-view-1305c7875853
#https://medium.com/egen/region-proposal-network-rpn-backbone-of-faster-r-cnn-4a744a38d7f9
#https://towardsdatascience.com/faster-r-cnn-object-detection-implemented-by-keras-for-custom-data-from-googles-open-images-125f62b9141a

#https://www.pyimagesearch.com/2018/09/03/semantic-segmentation-with-opencv-and-deep-learning/
#https://www.learnopencv.com/selective-search-for-object-detection-cpp-python/
#http://www.huppelen.nl/publications/selectiveSearchDraft.pdf

# %% [markdown]
# We're going to be using OpenCVs selective search segmentation algorithm. We will want to consider what kind of color scale we will use here. FOr now lets import in color.

# %%
#Selective search for object recognition. International journal of computer vision,

# %%
image = cv2.imread('.'+test1['root'][13]+test1['filename'][13])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(image)

# %%
ss.switchToSelectiveSearchFast()
rects = ss.process()

# %%
len(rects)
# Out:
# 551

# %%
rects[:10]
# Out:
# array([[171, 133,  29,  28],
#        [  0, 305,  46,  48],
#        [344, 287,  32,  88],
#        [286, 131,  68,  32],
#        [  0,   0, 133,  97],
#        [253, 280,  27,   6],
#        [260, 209,  32,  25],
#        [293, 240,  41,  43],
#        [315, 207, 108, 168],
#        [  0,  61, 149, 165]], dtype=int32)

# %% [markdown]
# rects return x1,y1, w,h

# %%
imOut = image.copy()
fig,ax = plt.subplots(1)
for i, rect in enumerate(rects):


    if (i < 200):

        x, y, w, h = rect
        #print(x,y,w,h)
        box=patches.Rectangle((x,y),w,h,linewidth=0.8,edgecolor=np.random.rand(3,),facecolor='none')
        ax.add_patch(box)
        #print(x,y,w,h)
        



plt.imshow(imOut)

# %%
rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))

# %%
imOut = image.copy()
fig,ax = plt.subplots(1)
for i, rect in enumerate(rects):


    if (i < 200):

        x, y, w, h = rect
        #print(x,y,w,h)
        box=patches.Rectangle((x,y),w,h,linewidth=0.8,edgecolor=np.random.rand(3,),facecolor='none')
        ax.add_patch(box)
        #print(x,y,w,h)
        



plt.imshow(imOut)

# %% [markdown]
# ## Calculate Intersection over Unioin

# %%
#https://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/

# %% [markdown]
# The IoU is a commonly used ratio or 'score' with how overlapped the proposed regions with our ground truth boxes. This is a common technique in pretty much every version of region-based CNNs. A score of 1 is one box totally overlaps the other, and 0 is there is no overlap. For our boundary box regression? problem, we will assign 1 to regions with a score of over 0.7 and 0 to regions with an IoU score of 0.3 and assignt nothing to those inbetween. We will also pass along our strong iou score windows for Feature Mapping(CNN).

# %% [markdown]
# Mean Average Precision
# precisions: List of precisions at different class score thresholds.
# recalls: List of recall values at different class score thresholds.
# overlaps: pred_boxes, gt_boxes IoU overlaps.

# %% [markdown]
# The thing is smaller boxes still totally INSIDE the ground truth box will stll have LOW scores if they are way smaller than the ground truth box ...

# %%
def calc_iou(box1,box2):

    
    left_max=max(box1['x1'],box2['x1'])
    right_min=min(box1['x2'],box2['x2'])
    top_min=min(box1['y2'],box2['y2'])
    bottom_max=max(box1['y1'],box2['y1'])
    if right_min < left_max or top_min < bottom_max:
        return 0.0
    
    
    
    area_of_intersect=(right_min-left_max)*(top_min-bottom_max)
    area_of_union=((box1['y2']-box1['y1'])*(box1['x2']-box1['x1']))+((box2['y2']-box2['y1'])*(box2['x2']-box2['x1']))-area_of_intersect
    iou=(area_of_intersect)/(area_of_union)
    assert iou >= 0.0
    assert iou <= 1.0

    return iou

# %% [markdown]
# Were going to loop through each image, get the ground truth box, run segmentation, utilize our IoU function, label regions with 1 for high iou and 0 for low iou and save all to list. We then do a binary classification problem on these regions

# %%
image = cv2.imread('.'+train1['root'][0]+train1['filename'][0])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(image)
ss.switchToSelectiveSearchFast()
rects = ss.process()
rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))

# %%
len(rects)
# Out:
# 400

# %%
box1={}
box1['x1']=round(float(train1['x1'][0]))
box1['x2']=round(float(train1['x2'][0]))
box1['y1']=round(float(train1['y1'][0]))
box1['y2']=round(float(train1['y2'][0]))

# %%
box1['w']=round(float(train1['w'][0]))
box1['h']=round(float(train1['h'][0]))

# %%
#rects = list(filter(lambda x : x[0]+x[2]<box1['w'], rects))

# %%
rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))

# %%
if (box1['x2']-box1['x1'])>(box1['y2']-box1['y1']):
    rects = list(filter(lambda x : x[2]>x[3], rects))
else:
    rects = list(filter(lambda x : x[2]<=x[3], rects))

# %%
# box1={}
# box1['x1']=round(float(test1['wing'][1]['xtl']))
# box1['x2']=round(float(test1['wing'][1]['xbr']))
# box1['y1']=round(float(test1['wing'][1]['ytl']))
# box1['y2']=round(float(test1['wing'][1]['ybr']))

# %%
fig,ax = plt.subplots(1)
for i,item in enumerate(rects):
    box2={}
    box2['x1']=rects[i][0]
    box2['y1']=rects[i][1]
    box2['x2']=rects[i][0]+rects[i][2]
    box2['y2']=rects[i][1]+rects[i][3]
    iou=calc_iou(box1,box2)
    if iou>0.7:
        #print(iou,i,item)



        x, y, w, h = rects[i]
        #print(x,y,w,h)
        box=patches.Rectangle((x,y),w,h,linewidth=0.8,edgecolor='green',facecolor='none')
        ax.add_patch(box)
        box3=patches.Rectangle((box1['x1'],box1['y1']),box1['x2']-box1['x1'],box1['y2']-box1['y1'],linewidth=0.8,edgecolor='red',facecolor='none')
        ax.add_patch(box3)
        print(iou)
plt.imshow(image)
plt.title('Proposed Regions w. IoU > 0.7')
# Out:
# 0.7650794210772338
# 0.8410680228862047
# 0.9030614272091545
# 0.8727550858232677
# 0.7133786848072562
# 0.8600054899807851
# 0.8369755244755245
# 0.8385935769656699
# 0.7690502727752684
# 0.9247159090909091
# 0.8444811450591797
# 0.8457280548109584
# 0.8328830260648442
# 0.7824352858371784
# 0.9339688157006003
# 0.7052655573284705
# 0.7085585585585585
# 0.7131800591850671
# 0.8204369040778363
# 0.7105442951491687
# 0.8485775588048315
# Text(0.5, 1.0, 'Proposed Regions w. IoU > 0.7')

# %% [markdown]
# rects[50]

# %%
print(box2)
print(box1)
# Out:
# {'x1': 0, 'y1': 176, 'x2': 480, 'y2': 360}
# {'x1': 7, 'x2': 423, 'y1': 67, 'y2': 309}

# %%
calc_iou(box1,box2)
# Out:
# 0.41393344505626045

# %% [markdown]
# #### WARNING Long Process time

# %% [markdown]
# This tidbit of code

# %%
train_images=[]
train_labels=[]
iou_scores=[]

# %%
##code adopted from 
##https://towardsdatascience.com/step-by-step-r-cnn-implementation-from-scratch-in-python-e97101ccde55
for i,item in enumerate(train1['filename']):
    try:

#     box1={}
#     box1['x1']=round(float(train1['wing'][i]['xtl']))
#     box1['x2']=round(float(train1['wing'][i]['xbr']))
#     box1['y1']=round(float(train1['wing'][i]['ytl']))
#     box1['y2']=round(float(train1['wing'][i]['ybr']))
    
#     box2={}
#     box2['x1']=round(float(train1['head'][i]['xtl']))
#     box2['x2']=round(float(train1['head'][i]['xbr']))
#     box2['y1']=round(float(train1['head'][i]['ytl']))
#     box2['y2']=round(float(train1['head'][i]['ybr']))
        box1={}
        box1['x1']=round(float(train1['x1'][i]))
        box1['x2']=round(float(train1['x2'][i]))
        box1['y1']=round(float(train1['y1'][i]))
        box1['y2']=round(float(train1['y2'][i]))
        
        
        
        image = cv2.imread('.'+train1['root'][i]+train1['filename'][i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        
        
        ss.switchToSelectiveSearchQuality()
        rects = ss.process()
        rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))
#         if (box1['x2']-box1['x1'])>(box1['y2']-box1['y1']):
#             rects = list(filter(lambda x : x[2]>x[3], rects))
#         else:
#             rects = list(filter(lambda x : x[2]<=x[3], rects))
    
#         rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))
        
        imout=image.copy()
        
        counter1=0
        counter2=0
        flag=0
        fflag=0
        bflag=0
        for j,item in enumerate(rects):
            if j<2000 and flag==0:
                box3={}
                box3['x1']=rects[j][0]
                box3['y1']=rects[j][1]
                box3['x2']=rects[j][0]+rects[j][2]
                box3['y2']=rects[j][1]+rects[j][3]
                iou_score=calc_iou(box1,box3)
                if counter1<30:
                    if iou_score>0.65:
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']]
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        train_images.append(resized)
                        train_labels.append(1)
                        counter1+=1
                        print('yes')
                else:
                    fflag=1
                if counter2<30:
                    if iou_score<0.3:
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']] 
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        train_images.append(resized)
                        train_labels.append(0)
                        counter2+=1
                
                else:
                    bflag=1
                    
            if fflag==1 and bflag==1:
                print('inside')
                flag=1
    except Exception as j:
        print(j)
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
test_images=[]
test_labels=[]

# %%
for i,item in enumerate(test1['filename']):
    try:

#     box1={}
#     box1['x1']=round(float(test1['wing'][i]['xtl']))
#     box1['x2']=round(float(test1['wing'][i]['xbr']))
#     box1['y1']=round(float(test1['wing'][i]['ytl']))
#     box1['y2']=round(float(test1['wing'][i]['ybr']))
    
#     box2={}
#     box2['x1']=round(float(test1['head'][i]['xtl']))
#     box2['x2']=round(float(test1['head'][i]['xbr']))
#     box2['y1']=round(float(test1['head'][i]['ytl']))
#     box2['y2']=round(float(test1['head'][i]['ybr']))
        box1={}
        box1['x1']=round(float(test1['x1'][i]))
        box1['x2']=round(float(test1['x2'][i]))
        box1['y1']=round(float(test1['y1'][i]))
        box1['y2']=round(float(test1['y2'][i]))
        
        
        
        image = cv2.imread('.'+test1['root'][i]+test1['filename'][i])

        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        
        ss.switchToSelectiveSearchQuality()
        rects = ss.process()
        rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))
#         if (box1['x2']-box1['x1'])>(box1['y2']-box1['y1']):
#             rects = list(filter(lambda x : x[2]>x[3], rects))
#         else:
#             rects = list(filter(lambda x : x[2]<=x[3], rects))
    
#         rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))
        
        imout=image.copy()
        
        counter1=0
        counter2=0
        flag=0
        fflag=0
        bflag=0
        for j,item in enumerate(rects):
            if j<2000 and flag==0:
                box3={}
                box3['x1']=rects[j][0]
                box3['y1']=rects[j][1]
                box3['x2']=rects[j][0]+rects[j][2]
                box3['y2']=rects[j][1]+rects[j][3]
                iou_score=calc_iou(box1,box3)
                if counter1<30:
                    if iou_score>0.65:
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']]
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        test_images.append(resized)
                        test_labels.append(1)
                        counter1+=1
                        print('yes')
                else:
                    fflag=1
                if counter2<30:
                    if iou_score<0.3:
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']] 
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        test_images.append(resized)
                        test_labels.append(0)
                        counter2+=1
                
                else:
                    bflag=1
                    
            if fflag==1 and bflag==1:
                print('inside')
                flag=1
    except Exception as j:
        print(j)
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
count=0
for i in test_labels:
    if i==0:
        count+=1
print(count)
# Out:
# 524

# %%
print(len(train_images))
print(len(train_labels))
# Out:
# 1289
# 1289

# %%
print(len(test_images))
print(len(test_labels))
# Out:
# 665
# 665

# %%
X_train=np.array(train_images)

# %%
y_train=np.array(train_labels)

# %%
X_test=np.array(test_images)

# %%
y_test=np.array(test_labels)

# %%
from sklearn.metrics import accuracy_score

# %%
X_train.shape
# Out:
# (1289, 224, 224)

# %%
X_test.shape
# Out:
# (665, 50176)

# %%
nsamples, nx, ny = X_train.shape
X_train = X_train.reshape((nsamples,nx*ny))

# %%
nsamples, nx, ny = X_test.shape
X_test = X_test.reshape((nsamples,nx*ny))

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
lenc = MyLabelBinarizer()
y_train =  lenc.fit_transform(y_train)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train, y=y_train)
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
X_train
# Out:
# array([[175, 175, 175, ..., 163, 163, 163],
#        [142, 142, 142, ...,  70,  70,  70],
#        [ 75,  75,  75, ...,  61,  61,  61],
#        ...,
#        [201, 202, 202, ..., 203, 194, 190],
#        [215, 214, 214, ..., 168, 175, 184],
#        [204, 205, 206, ..., 198, 200, 203]], dtype=uint8)

# %%
svc = SVC(gamma="scale")

# %%
svc.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# %%time
y_pred = svc.predict(X_test)
# Out:
# CPU times: user 17 s, sys: 97 ms, total: 17.1 s
# Wall time: 17.1 s

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8240601503759398

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
# %%time
y_pred = knn.predict(X_test)
# Out:
# CPU times: user 58 s, sys: 130 ms, total: 58.1 s
# Wall time: 58.2 s

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7879699248120301

# %%
clf=LinearSVC(random_state=1881)

# %%
clf.fit(X_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=1881, tol=0.0001,
#           verbose=0)

# %%
clf=LinearSVC(random_state=1881)

# %%
svc = SVC(gamma="scale")

# %%
svc.fit(X_train, y_train)

# %%
#https://www.pyimagesearch.com/2014/11/17/non-maximum-suppression-object-detection-python/

# %%
#https://gist.github.com/CMCDragonkai/1be3402e261d3c239a307a3346360506

# %% [markdown]
# ## VGG16

# %% [markdown]
# VGG16 is a popular CNN framework we will impliment here

# %%
##https://github.com/keras-team/keras-applications/blob/master/keras_applications/vgg16.py
input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=32,
                                      data_format=backend.image_data_format(),
                                      require_flatten=include_top,
                                      weights=weights)

if input_tensor is None:
        img_input = layers.Input(shape=input_shape)
else:
    if not backend.is_keras_tensor(input_tensor):
            img_input = layers.Input(tensor=input_tensor, shape=input_shape)
    else:
            img_input = input_tensor
    # Block 1
x=Conv2D(64, (3, 3),activation='relu',padding='same',name='block1_conv1')(img_input)
x=Conv2D(64, (3, 3),activation='relu',padding='same',name='block1_conv2')(x)
x=MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

# Block 2
x=Conv2D(128, (3, 3),activation='relu',padding='same',name='block2_conv1')(x)
x=Conv2D(128, (3, 3), activation='relu',padding='same',name='block2_conv2')(x)
x=MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

# Block 3
x=Conv2D(256, (3, 3),activation='relu',padding='same',name='block3_conv1')(x)
x=Conv2D(256, (3, 3),activation='relu',padding='same',name='block3_conv2')(x)
x=Conv2D(256, (3, 3),activation='relu',padding='same',name='block3_conv3')(x)
x=MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

# # Block 4
# x=Conv2D(512, (3, 3),activation='relu',padding='same',name='block4_conv1')(x)
# x=Conv2D(512, (3, 3),activation='relu',padding='same',name='block4_conv2')(x)
# x=Conv2D(512, (3, 3),activation='relu',padding='same',name='block4_conv3')(x)
# x=MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

# # Block 5
# x=Conv2D(512, (3, 3), activation='relu',padding='same',name='block5_conv1')(x)
# x=Conv2D(512, (3, 3), activation='relu',padding='same',name='block5_conv2')(x)
# x=Conv2D(512, (3, 3),activation='relu', padding='same', name='block5_conv3')(x)
# x=MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

# %%
# rects = ss.process()
# numShowRects = 100
# increment = 50
# imOut = image.copy()
# for i, rect in enumerate(rects):
#     if (i < numShowRects):

#         x, y, w, h = rect
#         patches.Rectangle((x,y),x+w,y+h,linewidth=1,edgecolor=np.random.rand(3,),facecolor='none')
#         #cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
    
# cv2.imshow("Output", imOut)


#     rect =

# %%
def bili_pooling(x):
    shp = K.shape(x)
    bsz, w, h, c = shp[0], shp[1], shp[2], shp[3]
    
    # Bilinear pooling
    b1 = K.reshape(x, (bsz * w * h, c, 1))
    b2 = K.reshape(x, (bsz * w * h, 1, c))
    d  = K.reshape(K.batch_dot(b1, b2), (bsz, w * h, c, c))
    d = K.sum(d, 1)
    
    # Flatten
    d = K.reshape(d, (bsz, c * c))
    
    # Normalize
    d = K.sqrt(K.relu(d))
    d = K.l2_normalize(d, -1)
    return d

# %%
     
    #https://stackoverflow.com/questions/25349178/calculating-percentage-of-bounding-box-overlap-for-image-detector-evaluation
