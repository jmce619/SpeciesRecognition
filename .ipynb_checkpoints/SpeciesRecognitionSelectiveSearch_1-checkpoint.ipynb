# %% [markdown]
# # Object Detection And Classification For Species Recognition

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Around 12% of current bird species are considered endangered, threatened or vulnerable in some way. Many birds play a crucial roll in ecological systems for both predator and prey. Bird species such as these are known as 'keystone species' that hold an invaluable presence in their respective ecosystems. For example, a lot of birds are host to a variety of parasites and flys that also hold weight within their food chains. Additionally, many birds aid in pollination of certain plant species and creation of subhabitats such as nests or entry points in trees (woodpecker). It is incredibly important to conserve these species for both ecological and humane reasons. Not to mention, birds are peculiar and amusing to us. It would be a shame to go out on a walk and not hear the specific chirping melody based on the regional species.
# What we can do is propose a habitat protection movement. Habitat loss and destruction are one of the leading causes of bird species extinction. We can discretely place cameras in areas we know there may be endangered species and are being considered for deforestation or other means of habitat disruption. We will attempt to train our own bird detection system so that we can appropriately assess the population and activity of specific species within our geographical regions of study. Working with local governments and species conservation groups, we can present our data and work against habitat loss.

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# We used a combination of images from Cal-Tech's bird data set . Cal-Tech's bird data set includes 200 species of around 80 images per species. We have abridged the dataset to 3 species of around 80 images per species. The species we will be considering include a Cardinal, Black-footed Albatross, and Western Meadowlark. The intended outcome of our study is to analyze various methods of segmentation and object detection, as opposed to produced a highly accurate bird classification model (although we will include classification). Image segmentation allows us to extract and separate different regions within our image. We are going to apply a selective search approach. We will then apply and evaluate a Convolutional Neural Network that will help us determine which segments are of interest (bird) and which are not (background noise, other animals,..so on)

# %% [markdown]
# Selective Search
# - Diverse application of grouping/segmentation algorithms based on color/texture/shape
# - Proposes multiple regions of interest
# - Heirarchical

# %% [markdown]
# As with many image recognition and object detection problems, we run into many recurrent and expected problems. We must consider how we will account for birds with different poses, facing different directions, leaning forwards or backwards, facing the camera or facing away, flying or standing, and so on. If we feed in images of birds in only certain poses, lets say all facing left, how will our detection system recognize a bird facing right. We also have to considered different background classes. Different bird species will habit different genres of terrain(what region are these species found in), and similarly we have to account for what season it is, weather conditions, time of day, lighting, etc.. We have accounted for some of these issues with data augmentation where we have generated copies of our original data with added noise that can be considered synonymous with camera inconsistencies (scratching,dust) and orientation flips (pose left,right). Our augmentation was minimal given time constraints and annotations, so we are avoiding rotation.
#
# For both approaches, we fit and evaluated various classification algorithms in a binary setting (foreground,background). We use our annotated boundary boxes on our birds so we can retrieve suggested candidate regions for foreground objects. We calculated an Intersection over Union score (IoU) to determine how overlapped our proposed regions by our segmentation are with our ground truth (annoted labels) box. Regions with a score greater than 0.7 would be classified as foreground and regions with a score less than 0.3 would be classified as background. Scores between 0.7 and 0.3 are ignored. Our classification model consists out a multi layer Convalutional Network connected to a Fully Connected layer.

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# | Name| Data Types (Pandas) | Description |
# |---|---|---|
# |root|object|root file path of image|
# |filename|object|full filename plus doc ext of image file|
# |w|int64|width of image|
# |h|int64|height of image|
# |x1|int64|first x-coordinate of bounding box|
# |y1|int64|first y-coordinate of bounding box|
# |x2|int64|second x-coordinate of bounding box|
# |y2|int64|second y-coordinate of bounding box|

# %%
import tensorflow as tf
import IPython.display as display

# %%
import base64
from PIL import Image
import io

from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3056662181597312036
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3135687884
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7432179099233399782
# physical_device_desc: "device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Flatten,Dense, ZeroPadding2D, Dropout, Input
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sn

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Flatten,Dense, ZeroPadding2D, Dropout, Input

import cv2

from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix, auc
from sklearn.preprocessing import LabelBinarizer

import xml.etree.ElementTree as ET

# %%
#load data with pandas
train_path='./data/bird2_train/'
test_path='./data/bird2_test/'

# %% [markdown]
# ## Read in CVAT annotion file with XML parser

# %% [markdown]
# We performed annotations (labeled boundary boxes) on our images around birds so we can set up an object detection model. These annotations were performed in Computer Vision Annotation Tool (CVAT). CVAT spits out an XML containing our image metadata, such as heigh, width, boundary box coordinate, and so on. We will parse through this XML with xml tree and create our initial dataframe.

# %%
def create_df_xml(input1):
    annotation=ET.parse(f'./data/bird2_{input1}/{input1}_annotations.xml')
    root=annotation.getroot()
    df_cols=['root','filename','w','h']
    df_rows=[]
    for node in root.iter('image'):
        #print (list(node.attrib.values()))
        s_root=f'/data/bird2_{input1}/'
        s_name=list(node.attrib.values())[1]
        s_height=list(node.attrib.values())[3]
        s_width=list(node.attrib.values())[2]
         
        
    
        df_rows.append({'root':s_root,'filename': s_name,'w':s_width,'h':s_height,
                            })
        x1=pd.DataFrame(df_rows, columns = df_cols)
    df_cols=['x1','x2','y1','y2']
    df_rows=[]
    for node in root.iter('image'):
        for node1 in node:
            s_x1=list(node1.attrib.values())[2]
            s_x2=list(node1.attrib.values())[4]
            s_y1=list(node1.attrib.values())[3]
            s_y2=list(node1.attrib.values())[5]
   
            df_rows.append({
                            'x1':s_x1,'x2':s_x2,'y1':s_y1,'y2':s_y2})
        x2=pd.DataFrame(df_rows,columns=df_cols)
    x4= pd.concat((x1,x2),axis=1)    
    return x4

# %%
#apply to test and train sets
test1=create_df_xml('test')
train1=create_df_xml('train')

# %%
#lets get a look at our data
train1.head()
# Out:
#                  root                                filename    w    h  \
# 0  /data/bird2_train/                      70095201-480px.jpg  480  360
# 1  /data/bird2_train/      Black_Footed_Albatross_0002_55.jpg  500  347
# 2  /data/bird2_train/  Black_Footed_Albatross_0042_796071.jpg  500  356
# 3  /data/bird2_train/  Black_Footed_Albatross_0051_796103.jpg  500  391
# 4  /data/bird2_train/  Black_Footed_Albatross_0056_796078.jpg  500  390
#
#        x1      x2      y1      y2
# 0    6.72  422.55   67.11  308.78
# 1   12.04  403.98  109.90  298.88
# 2  134.72  442.23   82.85  261.11
# 3   79.58  411.60   88.58  238.16
# 4  147.48  345.61   88.37  259.90

# %%
test1.head()
# Out:
#                 root                                filename    w    h  \
# 0  /data/bird2_test/  Black_Footed_Albatross_0033_796086.jpg  500  375
# 1  /data/bird2_test/     Black_Footed_Albatross_0038_212.jpg  500  332
# 2  /data/bird2_test/  Black_Footed_Albatross_0039_796132.jpg  500  500
# 3  /data/bird2_test/  Black_Footed_Albatross_0057_796106.jpg  500  337
# 4  /data/bird2_test/  Black_Footed_Albatross_0063_796141.jpg  288  192
#
#        x1      x2      y1      y2
# 0   36.18  440.24   62.17  238.15
# 1  134.41  429.68   61.48  223.27
# 2  150.79  460.31  151.71  354.56
# 3   69.41  362.56   40.22  266.45
# 4   47.44  243.70   26.67  140.82

# %%
#some quick conversions
train1['w']=train1['w'].astype(int)
train1['h']=train1['h'].astype(int)
train1['x1']=train1['x1'].astype(float).round().astype(int)
train1['x2']=train1['x2'].astype(float).round().astype(int)
train1['y1']=train1['y1'].astype(float).round().astype(int)
train1['y2']=train1['y2'].astype(float).round().astype(int)

# %%
test1['w']=test1['w'].astype(int)
test1['h']=test1['h'].astype(int)
test1['x1']=test1['x1'].astype(float).round().astype(int)
test1['x2']=test1['x2'].astype(float).round().astype(int)
test1['y1']=test1['y1'].astype(float).round().astype(int)
test1['y2']=test1['y2'].astype(float).round().astype(int)

# %% [markdown]
# ## Image Augmentation

# %% [markdown]
# Augmentation is different from preprocessing in the sense that it is only applied on our training data. It is used to make our data more robust so we can account for a broader variety of image classes.

# %% [markdown]
# ### Read in TF Record from Roboflow.ai

# %% [markdown]
# Roboflow is an online augmentation platform that allows us to perform augmentations on our image that will also be applied to our annotations. We uploaded our images and their associated annotations and applied several augmentations per image including: random rotation, horizontal flip, noise generation, and brightness adjustment. We then generate a TFRecord from

# %%
# followed TF documentation https://www.tensorflow.org/tutorials/load_data/tfrecord
raw_image_dataset = tf.data.TFRecordDataset('./data/train/birds.tfrecord')

# %%
image_feature_description = {
    'image/filename': tf.io.FixedLenFeature([], tf.string),
    'image/height': tf.io.FixedLenFeature([], tf.int64),
    'image/width': tf.io.FixedLenFeature([], tf.int64),
    'image/encoded': tf.io.FixedLenFeature([], tf.string),
    'image/object/bbox/xmin':tf.io.FixedLenFeature([], tf.float32),
    'image/object/bbox/xmax':tf.io.FixedLenFeature([], tf.float32),
    'image/object/bbox/ymin':tf.io.FixedLenFeature([], tf.float32),
    'image/object/bbox/ymax':tf.io.FixedLenFeature([], tf.float32)

}

# %%
def _parse_image_function(example_proto):
  # Parse the input tf.Example proto using the dictionary above.
  return tf.io.parse_single_example(example_proto, image_feature_description)

parsed_image_dataset = raw_image_dataset.map(_parse_image_function)
parsed_image_dataset
# Out:
# <MapDataset shapes: {image/encoded: (), image/filename: (), image/height: (), image/object/bbox/xmax: (), image/object/bbox/xmin: (), image/object/bbox/ymax: (), image/object/bbox/ymin: (), image/width: ()}, types: {image/encoded: tf.string, image/filename: tf.string, image/height: tf.int64, image/object/bbox/xmax: tf.float32, image/object/bbox/xmin: tf.float32, image/object/bbox/ymax: tf.float32, image/object/bbox/ymin: tf.float32, image/width: tf.int64}>

# %%
df_cols=['root','filename','w','h','x1','x2','y1','y2']
df_rows=[]

for i,image_features in enumerate(parsed_image_dataset):
    

    s_root='/data/bird2_train/'
    image_raw = image_features['image/encoded'].numpy()
    image_height=image_features['image/height'].numpy()
    image_width=image_features['image/width'].numpy()
    image_x1=int(round(image_features['image/object/bbox/xmin'].numpy()*image_width))
    image_x2=int(round(image_features['image/object/bbox/xmax'].numpy()*image_width))
    image_y1=int(round(image_features['image/object/bbox/ymin'].numpy()*image_height))
    image_y2=int(round(image_features['image/object/bbox/ymax'].numpy()*image_height))
    filename=str(image_features['image/filename'].numpy())
    
    start = "b'"
    end = ".rf"
    s = filename
    filename=s[s.find(start)+len(start):s.rfind(end)]
        
    image = Image.open(io.BytesIO(image_raw))
    image.save(f'./data/bird2_train/{filename}_{i}'+'.jpg', 'jpeg')
    filename=f'{filename}_{i}'
    
    df_rows.append({'root':s_root,'filename':filename+'.jpg','w':image_width,'h':image_height,'x1':image_x1,'x2':image_x2,
                    'y1':image_y1,'y2':image_y2
                            })
x4=pd.DataFrame(df_rows, columns = df_cols)

# %%
filename
# Out:
# 'Western_Meadowlark_0108_78155_jpg_245'

# %%
x4
# Out:
#                    root                                        filename    w  \
# 0    /data/bird2_train/         Western_Meadowlark_0048_78354_jpg_0.jpg  332
# 1    /data/bird2_train/         Western_Meadowlark_0112_78760_jpg_1.jpg  500
# 2    /data/bird2_train/         Western_Meadowlark_0091_78576_jpg_2.jpg  500
# 3    /data/bird2_train/    Black_Footed_Albatross_0060_796076_jpg_3.jpg  320
# 4    /data/bird2_train/                   Cardinal_0075_17946_jpg_4.jpg  399
# ..                  ...                                             ...  ...
# 241  /data/bird2_train/       Western_Meadowlark_0048_78354_jpg_241.jpg  332
# 242  /data/bird2_train/                 Cardinal_0079_19044_jpg_242.jpg  500
# 243  /data/bird2_train/  Black_Footed_Albatross_0042_796071_jpg_243.jpg  500
# 244  /data/bird2_train/  Black_Footed_Albatross_0056_796078_jpg_244.jpg  500
# 245  /data/bird2_train/       Western_Meadowlark_0108_78155_jpg_245.jpg  500
#
#        h   x1   x2   y1   y2
# 0    500   18  255  110  371
# 1    400  133  384    0  295
# 2    386  113  403   69  278
# 3    240   17  312   52  229
# 4    500  132  301  141  339
# ..   ...  ...  ...  ...  ...
# 241  500   32  248  110  354
# 242  346  235  367   57  201
# 243  356   55  382   47  280
# 244  390  171  349  115  254
# 245  375   33  291   78  269
#
# [246 rows x 8 columns]

# %% [markdown]
# Lets take a look at some of our augmentations.

# %% [markdown]
# #### Brightness

# %%
image = cv2.imread('.'+x4['root'][17]+x4['filename'][17])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# #### Random Rotation

# %%
image = cv2.imread('.'+x4['root'][26]+x4['filename'][26])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# #### Noise + Rotation

# %%
image = cv2.imread('.'+x4['root'][47]+x4['filename'][47])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
#concat augmented data with original data
train2=pd.concat((train1,x4),ignore_index=True)

# %%
train2.head(15)
# Out:
#                   root                                filename    w    h   x1  \
# 0   /data/bird2_train/                      70095201-480px.jpg  480  360    7
# 1   /data/bird2_train/      Black_Footed_Albatross_0002_55.jpg  500  347   12
# 2   /data/bird2_train/  Black_Footed_Albatross_0042_796071.jpg  500  356  135
# 3   /data/bird2_train/  Black_Footed_Albatross_0051_796103.jpg  500  391   80
# 4   /data/bird2_train/  Black_Footed_Albatross_0056_796078.jpg  500  390  147
# 5   /data/bird2_train/  Black_Footed_Albatross_0060_796076.jpg  320  240   11
# 6   /data/bird2_train/  Black_Footed_Albatross_0061_796082.jpg  240  187   50
# 7   /data/bird2_train/     Black_Footed_Albatross_0076_417.jpg  500  441   74
# 8   /data/bird2_train/     Black_Footed_Albatross_0081_426.jpg  500  320   94
# 9   /data/bird2_train/                 Cardinal_0051_17223.jpg  500  421   11
# 10  /data/bird2_train/                 Cardinal_0052_18334.jpg  500  330   33
# 11  /data/bird2_train/                 Cardinal_0053_17541.jpg  377  500   61
# 12  /data/bird2_train/                 Cardinal_0054_19334.jpg  435  500   64
# 13  /data/bird2_train/                 Cardinal_0055_18898.jpg  500  333  293
# 14  /data/bird2_train/                 Cardinal_0056_18352.jpg  500  375   95
#
#      x2   y1   y2
# 0   423   67  309
# 1   404  110  299
# 2   442   83  261
# 3   412   89  238
# 4   346   88  260
# 5   292   78  211
# 6   209   25  162
# 7   426  115  324
# 8   357   75  250
# 9   189  191  408
# 10  396   88  259
# 11  281   86  448
# 12  387   73  443
# 13  438   77  327
# 14  441    0  293

# %% [markdown]
# ## Ground truth boxes

# %% [markdown]
# Our ground truth boxes is our annotated boundary box that we use to 'hint' at the computer to pick up segments nearby. Lets take a peak.

# %%
train2['filename'][5]
# Out:
# 'Black_Footed_Albatross_0060_796076.jpg'

# %%
'.'+train2['root'][5]+train2['filename'][5]
# Out:
# './data/bird2_train/Black_Footed_Albatross_0060_796076.jpg'

# %%
def bbox_plot(i):

    image = cv2.imread('.'+train2['root'][i]+train2['filename'][i])
    image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    x1=train2['x1'][i]
    x2=train2['x2'][i]
    y1=train2['y1'][i]
    y2=train2['y2'][i]

    fig,ax = plt.subplots(1)
    ax.imshow(image)
    rect = patches.Rectangle((x1,y1),x2-x1,y2-y1,linewidth=3,edgecolor=np.random.rand(3,),facecolor='none')
    ##(x1,y1),x2-x1,y2-y1
    ax.add_patch(rect)
    print(x1,x2,y1,y2)
    return plt.imshow(image)

# %%
def bbox_plot1(i):

    image = cv2.imread('.'+test1['root'][i]+test1['filename'][i])
    image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    x1=test1['x1'][i]
    x2=test1['x2'][i]
    y1=test1['y1'][i]
    y2=test1['y2'][i]

    fig,ax = plt.subplots(1)
    ax.imshow(image)
    rect = patches.Rectangle((x1,y1),x2-x1,y2-y1,linewidth=3,edgecolor=np.random.rand(3,),facecolor='none')
    ##(x1,y1),x2-x1,y2-y1
    ax.add_patch(rect)
    print(x1,x2,y1,y2)
    return plt.imshow(image)

# %%
bbox_plot(5)
# Out:
# 11 292 78 211

# %%
bbox_plot(13)
# Out:
# 293 438 77 327

# %% [markdown]
# ## Region Proposal System

# %%
#https://www.pyimagesearch.com/2018/09/03/semantic-segmentation-with-opencv-and-deep-learning/
#https://www.learnopencv.com/selective-search-for-object-detection-cpp-python/

# %%
#http://www.huppelen.nl/publications/selectiveSearchDraft.pdf

# %% [markdown]
# We're going to be using OpenCVs selective search segmentation algorithm. Please refer to the above paper if you would like a more in depth look of how Selective Search was built off its predecessors. In general, Selective Search applies a wide variety of algorithms on multiples scales and looks to segment out images. The segmentations are based on region characteristics and similarities in color,texture, and size. OpenCVs method of segmentations returns the coordinates for us in a bounding box format.

# %% [markdown]
# ### Segmentation Examples

# %%
#read in our image and convert to color
image = cv2.imread('.'+test1['root'][13]+test1['filename'][13])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %% [markdown]
# Basic color image of our cardinal we want to segment.

# %%
cv2.setUseOptimized(True)

# %%
##Initiate Segmentation
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
##Set base image to our specific ingest image
ss.setBaseImage(image)

# %%
# %%time
##Selecting Quality Search over Fast, lower recall rate but higher rate of proposals
##(refer to #http://www.huppelen.nl/publications/selectiveSearchDraft.pdf)
ss.switchToSelectiveSearchQuality()
##Process our image
rects = ss.process()
print(f'we have {len(rects)} proposals')
# Out:
# we have 1861 proposals
# Wall time: 7.82 s

# %%
rects[:5]
# Out:
# array([[ 94, 138, 291, 170],
#        [384, 217,  70, 158],
#        [ 29, 289, 100,  86],
#        [104, 266,  29,  28],
#        [ 94, 191,  64,  58]], dtype=int32)

# %% [markdown]
# As we see above, ss.process() returns x1,y1, w,h coordinates of its segmented regions. Lets display the top 200 proposals from our algorithm.

# %%
imOut = image.copy()
fig,ax = plt.subplots(1)
t1=300
#loop through proposal coordinates
for i, rect in enumerate(rects):
    #for proposal count less than our threshold, display these proposals on our image
    if (i < t1):
        x, y, w, h = rect
        box=patches.Rectangle((x,y),w,h,linewidth=0.8,edgecolor=np.random.rand(3,),facecolor='none')
        ax.add_patch(box)
plt.title(f'number of proposed regions ={t1}')
    
plt.imshow(imOut)

# %% [markdown]
# One of our cardinal images that has been segmented with Quality Segmentation. Top 300 Regions.

# %%
image = cv2.imread('.'+test1['root'][19]+test1['filename'][19])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(image)
ss.switchToSelectiveSearchQuality()
rects = ss.process()
print(f'we have {len(rects)} proposals')
# Out:
# we have 1649 proposals

# %%
imOut = image.copy()
fig,ax = plt.subplots(1)
t1=100
for i, rect in enumerate(rects):
    if (i < t1):
        x, y, w, h = rect
        box=patches.Rectangle((x,y),w,h,linewidth=0.8,edgecolor=np.random.rand(3,),facecolor='none')
        ax.add_patch(box)
plt.title(f'number of proposed regions ={t1}')

        
plt.imshow(imOut)

# %% [markdown]
# ## Calculate Intersection over Unioin

# %%
#https://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/

# %% [markdown]
# The IoU is a ratio or 'score' associating how overlapped the proposed regions with our ground truth boxes. This is a common technique in pretty much every version of region-based CNNs. A score of 1 is one box totally overlaps the other, and 0 is there is no overlap. For our boundary box regression? problem, we will assign 1 to regions with a score of over 0.7 and 0 to regions with an IoU score of 0.3 and assignt nothing to those inbetween. We will also pass along our strong iou score windows for Feature Mapping(CNN).

# %% [markdown]
# The thing is smaller boxes still totally INSIDE the ground truth box will stll have LOW scores if they are way smaller than the ground truth box ...consider this.

# %%
def calc_iou(box1,box2):
   
    left_max=max(box1['x1'],box2['x1'])
    right_min=min(box1['x2'],box2['x2'])
    top_min=min(box1['y2'],box2['y2'])
    bottom_max=max(box1['y1'],box2['y1'])
    
    area_of_intersect=(right_min-left_max)*(top_min-bottom_max)
    area_of_union=((box1['y2']-box1['y1'])*(box1['x2']-box1['x1']))+((box2['y2']-box2['y1'])*(box2['x2']-box2['x1']))-area_of_intersect
    iou=(area_of_intersect)/(area_of_union)

    return iou

# %% [markdown]
# Were going to loop through each image, get the ground truth box, run segmentation, utilize our IoU function, label regions with 1 for high iou and 0 for low iou and save all to list. We then do a binary classification problem on these regions

# %% [markdown]
# ### High IoU Score Examples

# %%
image = cv2.imread('.'+train1['root'][0]+train1['filename'][0])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(image)
ss.switchToSelectiveSearchQuality()
rects = ss.process()
#rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))

# %%
len(rects)
# Out:
# 2097

# %%
box1={}
box1['x1']=round(float(train1['x1'][0]))
box1['x2']=round(float(train1['x2'][0]))
box1['y1']=round(float(train1['y1'][0]))
box1['y2']=round(float(train1['y2'][0]))

# %%
fig,ax = plt.subplots(1)
count=0
for i,item in enumerate(rects):
    box2={}
    box2['x1']=rects[i][0]
    box2['y1']=rects[i][1]
    box2['x2']=rects[i][0]+rects[i][2]
    box2['y2']=rects[i][1]+rects[i][3]
    iou=calc_iou(box1,box2)
    if iou>0.7:
        x, y, w, h = rects[i]
        box=patches.Rectangle((x,y),w,h,linewidth=0.8,edgecolor='green',facecolor='none')
        ax.add_patch(box)

        count+=1
box3=patches.Rectangle((box1['x1'],box1['y1']),box1['x2']-box1['x1'],box1['y2']-box1['y1'],linewidth=2,edgecolor='red',facecolor='none')
ax.add_patch(box3)
plt.imshow(image)
plt.title(f'{count} Regions w. IoU > 0.7')
# Out:
# Text(0.5, 1.0, '74 Regions w. IoU > 0.7')

# %% [markdown]
# Red box is our ground truth box. Green boxes are segmentations with IoU score > 0.7

# %%
image = cv2.imread('.'+train1['root'][15]+train1['filename'][15])
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(image)
ss.switchToSelectiveSearchQuality()
rects = ss.process()
len(rects)
box1={}
box1['x1']=round(float(train1['x1'][15]))
box1['x2']=round(float(train1['x2'][15]))
box1['y1']=round(float(train1['y1'][15]))
box1['y2']=round(float(train1['y2'][15]))

# %%
fig,ax = plt.subplots(1)
count=0
for i,item in enumerate(rects):
    box2={}
    box2['x1']=rects[i][0]
    box2['y1']=rects[i][1]
    box2['x2']=rects[i][0]+rects[i][2]
    box2['y2']=rects[i][1]+rects[i][3]
    iou=calc_iou(box1,box2)
    if iou>0.7:
        x, y, w, h = rects[i]
        box=patches.Rectangle((x,y),w,h,linewidth=0.8,edgecolor='green',facecolor='none')
        ax.add_patch(box)

        count+=1
box3=patches.Rectangle((box1['x1'],box1['y1']),box1['x2']-box1['x1'],box1['y2']-box1['y1'],linewidth=2,edgecolor='red',facecolor='none')
ax.add_patch(box3)
plt.imshow(image)
plt.title(f'{count} Regions w. IoU > 0.7')
# Out:
# Text(0.5, 1.0, '108 Regions w. IoU > 0.7')

# %% [markdown]
# ## Model Setup

# %% [markdown]
# #### WARNING Long Process time. Preforming segmentation on our training data set.

# %% [markdown]
# This tidbit of code will set up our binary classifier data but cropping out all the segments with greater than 0.7 IoU score, resizing them all to same size (need to do this to fit a model) and then appending them to our data set with a label of 1 for >0.7 IoU or 0 for <0.3 IoU score. We will disregard regions in between.

# %%
#Initiate training data set
train_images=[]
train_labels=[]

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %% [markdown]
# FIND AND REPLACE TRAIN2 OR TRAIN1 to use augmented or unaugmented data, respectively. Using train2 will take ~2Hours, train1 ~15mins. Model was trained on train1

# %%
##code adopted from 
##https://towardsdatascience.com/step-by-step-r-cnn-implementation-from-scratch-in-python-e97101ccde55

#loop through our dataframe and get our image filenames to read in
for i,item in enumerate(train1['filename']):
    try:
        #get our ground truth box
        box1={}
        box1['x1']=round(float(train1['x1'][i]))
        box1['x2']=round(float(train1['x2'][i]))
        box1['y1']=round(float(train1['y1'][i]))
        box1['y2']=round(float(train1['y2'][i]))
        
        
        #read in image
        image = cv2.imread('.'+train1['root'][i]+train1['filename'][i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        #run selective search
        ss.setBaseImage(image)
        ss.switchToSelectiveSearchQuality()
        rects = ss.process()
        #apply filters
#        rects = list(filter(lambda x : x[2]<x[3]*10 and x[3]<x[2]*10, rects))
#         if (box1['x2']-box1['x1'])>(box1['y2']-box1['y1']):
#             rects = list(filter(lambda x : x[2]>x[3], rects))
#         else:
#             rects = list(filter(lambda x : x[2]<=x[3], rects))
    
#         rects = list(filter(lambda x : x[2]<x[3]*3 and x[3]<x[2]*3, rects))
        
        imout=image.copy()
        
        #we want to set some limits to the number of classes we assign per image
        #we dont want to have unbalanced classes so we set a limit of 30 regions per image per label
        counter1=0
        counter2=0
        flag=0
        fflag=0
        bflag=0
        ##loop through proposed regions
        for j,item in enumerate(rects):
            #get top 2000 regions
            if j<2000 and flag==0:
                #assign proposed region coordinates to coordinate dictionary, similiar to our ground truth box.
                box3={}
                box3['x1']=rects[j][0]
                box3['y1']=rects[j][1]
                box3['x2']=rects[j][0]+rects[j][2]
                box3['y2']=rects[j][1]+rects[j][3]
                #calculate IoU score of ground truth with proposal
                iou_score=calc_iou(box1,box3)
                #check to make sure there are less than 40 positive classes for this image
                if counter1<40:
                    #if IoU score is high, greater than 0.7 lets assign it to positive class 1
                    if iou_score>0.7:
                        #crop out proposal
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']]
                        #resize for model input resampling using pixel area relation
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        #add image data to our train set
                        train_images.append(resized)
                        #append positive class
                        train_labels.append(1)
                        #increment counter
                        counter1+=1
                       # print('yes')
                else:
                    fflag=1
                if counter2<40:
                    #if iou_score is low, less than 0.3 lets assign it to negative class 0
                    if iou_score<0.3:
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']] 
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        train_images.append(resized)
                        train_labels.append(0)
                        counter2+=1
                
                else:
                    bflag=1
            #If we have 70 regions for botch classes within the image, we move on        
            if fflag==1 and bflag==1:
               # print('inside')
                flag=1
    except Exception as j:
        print(j)

# %%
#count data set
print(len(train_images))
print(len(train_labels))
# Out:
# 2644
# 2644

# %%
#count positive classes
count=0
for i in train_labels:
    if i==1:
        count+=1
print(count)
# Out:
# 964

# %% [markdown]
# ### Preform same steps on test data

# %% [markdown]
# We will preform the exact same preprocessing steps to our test data, refer to above cells.

# %%
test_images=[]
test_labels=[]

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
for i,item in enumerate(test1['filename']):
    try:

        box1={}
        box1['x1']=round(float(test1['x1'][i]))
        box1['x2']=round(float(test1['x2'][i]))
        box1['y1']=round(float(test1['y1'][i]))
        box1['y2']=round(float(test1['y2'][i]))
        
        
        
        image = cv2.imread('.'+test1['root'][i]+test1['filename'][i])

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        ss.setBaseImage(image)

        
        ss.switchToSelectiveSearchQuality()
        rects = ss.process()
        imout=image.copy()
        
        counter1=0
        counter2=0
        flag=0
        fflag=0
        bflag=0
        for j,item in enumerate(rects):
            if j<2000 and flag==0:
                box3={}
                box3['x1']=rects[j][0]
                box3['y1']=rects[j][1]
                box3['x2']=rects[j][0]+rects[j][2]
                box3['y2']=rects[j][1]+rects[j][3]
                iou_score=calc_iou(box1,box3)
                if counter1<30:
                    if iou_score>0.7:
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']]
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        test_images.append(resized)
                        test_labels.append(1)
                        counter1+=1
                       # print('yes')
                else:
                    fflag=1
                if counter2<30:
                    if iou_score<0.3:
                        timage=imout[box3['y1']:box3['y2'],box3['x1']:box3['x2']] 
                        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
                        test_images.append(resized)
                        test_labels.append(0)
                        counter2+=1
                
                else:
                    bflag=1
                    
            if fflag==1 and bflag==1:
               # print('inside')
                flag=1
    except Exception as j:
        print(j)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Baseline

# %% [markdown]
# First, let us determine a baseline accuracy score to compare against. Since we are doing a binary classification model, our baseline should be .50

# %%
print(len(test_images))
print(len(test_labels))
# Out:
# 1259
# 1259

# %%
count=0
for i in test_labels:
    if i==1:
        count+=1
print(count)
# Out:
# 509

# %%
X_train=np.array(train_images)

# %%
X_train.shape
# Out:
# (2644, 224, 224, 3)

# %%
y_train=np.array(train_labels)

# %%
X_test=np.array(test_images)

# %%
y_test=np.array(test_labels)

# %%
X_test.shape
# Out:
# (1259, 224, 224, 3)

# %% [markdown]
# ## Binary Classifier with CNN

# %% [markdown]
# We are going to set up a CNN model with framework such as (2xConv2D + 1xMaxPool)x4 + FCNN

# %%
X_train.shape
# Out:
# (2644, 224, 224, 3)

# %%
cnn = Sequential()
cnn.add(Conv2D(32, (3, 3),input_shape=(224,224,3), activation='relu'))
#cnn.add(ZeroPadding2D((1,1)))
cnn.add(Conv2D(32, (3, 3), activation='relu'))
cnn.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
# cnn.add(ZeroPadding2D((1,1)))
# cnn.add(Conv2D(128, (3, 3), activation='relu'))
# cnn.add(ZeroPadding2D((1,1)))
# cnn.add(Conv2D(128, (3, 3), activation='relu'))
# cnn.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
#cnn.add(ZeroPadding2D((1,1)))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
#cnn.add(ZeroPadding2D((1,1)))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
# cnn.add(ZeroPadding2D((1,1)))
# cnn.add(Conv2D(256, (3, 3), activation='relu'))
cnn.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
#cnn.add(ZeroPadding2D((1,1)))
cnn.add(Conv2D(128, (3, 3), activation='relu'))
#cnn.add(ZeroPadding2D((1,1)))
cnn.add(Conv2D(128, (3, 3), activation='relu'))
cnn.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
cnn.add(Conv2D(256, (3, 3), activation='relu'))
#cnn.add(ZeroPadding2D((1,1)))
cnn.add(Conv2D(256, (3, 3), activation='relu'))
cnn.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
# cnn.add(ZeroPadding2D((1,1)))
# cnn.add(Conv2D(512, (3, 3), activation='relu'))
# cnn.add(ZeroPadding2D((1,1)))
# cnn.add(Conv2D(512, (3, 3), activation='relu'))
# cnn.add(ZeroPadding2D((1,1)))
# cnn.add(Conv2D(512, (3, 3), activation='relu'))
# cnn.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
cnn.add(Flatten())

# %%
cnn.add(Dense(512, activation='relu'))
cnn.add(Dropout(0.2))
cnn.add(Dense(256, activation='relu'))
cnn.add(Dropout(0.2))
cnn.add(Dense(128, activation='relu'))
cnn.add(Dropout(0.2))
#cnn.add(Dense(500, activation='softmax'))

# %%
#cnn.add(Dense(2,activation='softmax'))

# %%
cnn.add(Dense(1,activation='sigmoid'))

# %%
cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])

# %%
early_stop=EarlyStopping(monitor='val_binary_accuracy',min_delta=0,patience=5,verbose=1,mode='auto')

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 106, 106, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 53, 53, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 51, 51, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 49, 49, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 22, 22, 256)       295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 20, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25600)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               13107712
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 14,444,321
# Trainable params: 14,444,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = cnn.fit(X_train,
                        y_train,
                        batch_size=32,
                        validation_data=(X_test, y_test),
                        epochs=20,
                        verbose=1,callbacks=[early_stop])
# Out:
# Train on 2644 samples, validate on 1259 samples
# Epoch 1/20
# 2644/2644 [==============================] - 33s 13ms/sample - loss: 0.7242 - binary_accuracy: 0.6694 - val_loss: 0.6274 - val_binary_accuracy: 0.7744
# Epoch 2/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.4916 - binary_accuracy: 0.7927 - val_loss: 0.3744 - val_binary_accuracy: 0.8562
# Epoch 3/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.3933 - binary_accuracy: 0.8510 - val_loss: 0.5635 - val_binary_accuracy: 0.8372
# Epoch 4/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.3285 - binary_accuracy: 0.8801 - val_loss: 0.4849 - val_binary_accuracy: 0.8459
# Epoch 5/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.2745 - binary_accuracy: 0.9104 - val_loss: 0.3607 - val_binary_accuracy: 0.8872
# Epoch 6/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.2699 - binary_accuracy: 0.9115 - val_loss: 0.6488 - val_binary_accuracy: 0.8451
# Epoch 7/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.2895 - binary_accuracy: 0.9047 - val_loss: 0.3699 - val_binary_accuracy: 0.8467
# Epoch 8/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.2629 - binary_accuracy: 0.9175 - val_loss: 0.6778 - val_binary_accuracy: 0.8507
# Epoch 9/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.2133 - binary_accuracy: 0.9300 - val_loss: 0.4792 - val_binary_accuracy: 0.8793
# Epoch 10/20
# 2644/2644 [==============================] - 26s 10ms/sample - loss: 0.1899 - binary_accuracy: 0.9425 - val_loss: 0.4881 - val_binary_accuracy: 0.8753
# Epoch 00010: early stopping

# %% [markdown]
# ## Results & Evaluation

# %% [markdown]
# We have trained a CNN to achieve 87.53% testing accuracy and 94.25% training accuracy, which is significantly higher than our 50% baseline model. We do have evidence of overfitting which we will want to address.

# %%
train_loss=history.history['loss']
test_loss=history.history['val_loss']
plt.figure(figsize=(12,8))
plt.plot(train_loss,label='Training loss', color='navy')
plt.plot(test_loss,label='Testing loss',color='skyblue')
plt.legend();

# %% [markdown]
# As we can see from our loss graph above, our model is somewhat overfit with testing loss increasing sightly as train loss decreases. We can combat overfitting by applying more augmentations, more regularization, or simplifying our model.

# %%
# pred = model1.predict(test_matrix)
# cm=metrics.confusion_matrix(test_labels,pred)
# print(cm)
# plt.imshow(cm, cmap='binary')

# %%
preds=cnn.predict(X_test)

# %%
preds[:5]
# Out:
# array([[0.07886718],
#        [0.08524376],
#        [0.17366731],
#        ...,
#        [0.94305307],
#        [0.8623884 ],
#        [0.998099  ]], dtype=float32)

# %%
test2=pd.DataFrame(y_test)

# %%
preds=pd.DataFrame(preds)

# %%
x=pd.concat((preds,test2),axis=1,ignore_index=False)

# %%
x.columns = ['pbird','isbird']

# %% [markdown]
# ### True Positives

# %%
x[(x['pbird']>0.5)&(x['isbird']==1)].head()
# Out:
#        pbird  isbird
# 30  0.793743       1
# 31  0.815713       1
# 32  0.862772       1
# 33  0.842156       1
# 34  0.892557       1

# %%
TP=x[(x['pbird']>0.5)&(x['isbird']==1)].shape[0]

# %% [markdown]
# ### True Negatives

# %%
x[(x['pbird']<0.5)&(x['isbird']==0)].head()
# Out:
#          pbird  isbird
# 0     0.078867       0
# 1     0.085244       0
# 2     0.173667       0
# 3     0.084972       0
# 4     0.099985       0
# ...        ...     ...
# 1224  0.118839       0
# 1225  0.135825       0
# 1226  0.127731       0
# 1227  0.061525       0
# 1228  0.044941       0
#
# [712 rows x 2 columns]

# %%
TN=x[(x['pbird']<0.5)&(x['isbird']==0)].shape[0]

# %% [markdown]
# ### False Positives

# %%
x[(x['pbird']>0.5)&(x['isbird']==0)].head()
# Out:
#          pbird  isbird
# 18    0.563603       0
# 102   0.671188       0
# 113   0.925498       0
# 116   0.897109       0
# 246   0.611152       0
# 351   0.972237       0
# 352   0.848692       0
# 358   0.996535       0
# 370   0.919148       0
# 374   0.513981       0
# 384   0.543891       0
# 432   0.970369       0
# 450   0.999599       0
# 461   0.928808       0
# 466   0.789404       0
# 473   0.590349       0
# 520   0.996468       0
# 526   0.516358       0
# 586   0.950428       0
# 596   0.999997       0
# 628   0.966291       0
# 702   0.953814       0
# 707   0.999418       0
# 712   0.995123       0
# 713   0.999717       0
# 724   0.618998       0
# 801   0.960374       0
# 841   0.999918       0
# 899   0.807076       0
# 900   0.522038       0
# 905   0.999999       0
# 906   0.999884       0
# 920   0.982507       0
# 950   0.756289       0
# 974   0.809439       0
# 1024  0.881581       0
# 1204  0.959141       0
# 1223  0.574999       0

# %%
FP=x[(x['pbird']>0.5)&(x['isbird']==0)].shape[0]

# %% [markdown]
# ### False Negatives

# %%
x[(x['pbird']<0.5)&(x['isbird']==1)].head()
# Out:
#          pbird  isbird
# 41    0.245296       1
# 56    0.151787       1
# 160   0.121951       1
# 161   0.079857       1
# 162   0.118375       1
# ...        ...     ...
# 1164  0.018809       1
# 1165  0.022603       1
# 1166  0.026480       1
# 1167  0.067483       1
# 1168  0.018481       1
#
# [119 rows x 2 columns]

# %%
FN=x[(x['pbird']<0.5)&(x['isbird']==1)].shape[0]

# %% [markdown]
# ## Confusion Matrix

# %%
array = [[TP,TN],
        [FP,FN]]
df_cm = pd.DataFrame(array, index = ['True','False'],
                  columns = ['Positive','Negative'])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True,fmt='1g')

# %% [markdown]
# Above we have our confusion matrix.

# %%
#https://www.pyimagesearch.com/2014/11/17/non-maximum-suppression-object-detection-python/

# %%
#https://gist.github.com/CMCDragonkai/1be3402e261d3c239a307a3346360506

# %% [markdown]
# ## BONUS (NMS AND SPECIES CLASSIFICATION)

# %% [markdown]
# If our model is strong enough and predicts multiple correct regions, we can apply non-max suppresion and then classify species.

# %% [markdown]
# ## Non-Max Suppression

# %% [markdown]
# ## Species Classifier

# %%
train_images=[]
train_labels=[]

# %%
for i,item in enumerate(train2['filename']):


    box1={}
    box1['x1']=round(float(train2['x1'][i]))
    box1['x2']=round(float(train2['x2'][i]))
    box1['y1']=round(float(train2['y1'][i]))
    box1['y2']=round(float(train2['y2'][i]))
        
        
        
    image = cv2.imread('.'+train2['root'][i]+train2['filename'][i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    imout=image.copy()
    if 'Western' in train2['filename'][i]:
        print(i,item)
        timage=imout[box1['y1']:box1['y2'],box1['x1']:box1['x2']]
        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
        train_images.append(resized)
        train_labels.append(1)
    if 'Black' in train2['filename'][i]:
        print(i,item)
        timage=imout[box1['y1']:box1['y2'],box1['x1']:box1['x2']]
        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
        train_images.append(resized)
        train_labels.append(2)
    if 'Cardinal' in train2['filename'][i]:
        print(i,item)
        timage=imout[box1['y1']:box1['y2'],box1['x1']:box1['x2']]
        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
        train_images.append(resized)
        train_labels.append(3)
    else:
        continue
# Out:
# 1 Black_Footed_Albatross_0002_55.jpg
# 2 Black_Footed_Albatross_0042_796071.jpg
# 3 Black_Footed_Albatross_0051_796103.jpg
# 4 Black_Footed_Albatross_0056_796078.jpg
# 5 Black_Footed_Albatross_0060_796076.jpg
# 6 Black_Footed_Albatross_0061_796082.jpg
# 7 Black_Footed_Albatross_0076_417.jpg
# 8 Black_Footed_Albatross_0081_426.jpg
# 9 Cardinal_0051_17223.jpg
# 10 Cardinal_0052_18334.jpg
# 11 Cardinal_0053_17541.jpg
# 12 Cardinal_0054_19334.jpg
# 13 Cardinal_0055_18898.jpg
# 14 Cardinal_0056_18352.jpg
# 15 Cardinal_0075_17946.jpg
# 16 Cardinal_0078_17181.jpg
# 17 Cardinal_0079_19044.jpg
# 18 Cardinal_0081_17291.jpg
# 19 Cardinal_0085_19162.jpg
# 20 Cardinal_0089_18005.jpg
# 21 Cardinal_0092_17591.jpg
# 22 Cardinal_0093_17676.jpg
# 23 Western_Meadowlark_0040_77823.jpg
# 24 Western_Meadowlark_0042_78180.jpg
# 25 Western_Meadowlark_0048_78354.jpg
# 26 Western_Meadowlark_0081_77798.jpg
# 27 Western_Meadowlark_0083_78197.jpg
# 28 Western_Meadowlark_0085_77745.jpg
# 29 Western_Meadowlark_0086_78636.jpg
# 30 Western_Meadowlark_0091_78576.jpg
# 31 Western_Meadowlark_0108_78155.jpg
# 32 Western_Meadowlark_0109_77990.jpg
# 33 Western_Meadowlark_0112_78760.jpg
# 34 Western_Meadowlark_0115_77882.jpg
# 35 Western_Meadowlark_0116_77862.jpg
# 36 Western_Meadowlark_0120_77834.jpg
# 42 Western_Meadowlark_0048_78354_jpg_0.jpg
# 43 Western_Meadowlark_0112_78760_jpg_1.jpg
# 44 Western_Meadowlark_0091_78576_jpg_2.jpg
# 45 Black_Footed_Albatross_0060_796076_jpg_3.jpg
# 46 Cardinal_0075_17946_jpg_4.jpg
# 47 Western_Meadowlark_0116_77862_jpg_5.jpg
# 48 Cardinal_0081_17291_jpg_6.jpg
# 49 Western_Meadowlark_0048_78354_jpg_7.jpg
# 50 Cardinal_0093_17676_jpg_8.jpg
# 52 Western_Meadowlark_0109_77990_jpg_10.jpg
# 53 Black_Footed_Albatross_0042_796071_jpg_11.jpg
# 54 Cardinal_0054_19334_jpg_12.jpg
# 55 Western_Meadowlark_0040_77823_jpg_13.jpg
# 56 Cardinal_0052_18334_jpg_14.jpg
# 58 Western_Meadowlark_0081_77798_jpg_16.jpg
# 59 Western_Meadowlark_0091_78576_jpg_17.jpg
# 60 Black_Footed_Albatross_0002_55_jpg_18.jpg
# 61 Western_Meadowlark_0086_78636_jpg_19.jpg
# 62 Cardinal_0053_17541_jpg_20.jpg
# 63 Black_Footed_Albatross_0056_796078_jpg_21.jpg
# 64 Cardinal_0075_17946_jpg_22.jpg
# 65 Black_Footed_Albatross_0051_796103_jpg_23.jpg
# 66 Cardinal_0093_17676_jpg_24.jpg
# 67 Western_Meadowlark_0112_78760_jpg_25.jpg
# 68 Cardinal_0079_19044_jpg_26.jpg
# 69 Western_Meadowlark_0085_77745_jpg_27.jpg
# 70 Cardinal_0054_19334_jpg_28.jpg
# 72 Cardinal_0078_17181_jpg_30.jpg
# 73 Black_Footed_Albatross_0042_796071_jpg_31.jpg
# 74 Black_Footed_Albatross_0002_55_jpg_32.jpg
# 75 Cardinal_0056_18352_jpg_33.jpg
# 76 Cardinal_0079_19044_jpg_34.jpg
# 77 Western_Meadowlark_0040_77823_jpg_35.jpg
# 78 Cardinal_0079_19044_jpg_36.jpg
# 79 Black_Footed_Albatross_0081_426_jpg_37.jpg
# 80 Black_Footed_Albatross_0051_796103_jpg_38.jpg
# 81 Cardinal_0051_17223_jpg_39.jpg
# 82 Black_Footed_Albatross_0061_796082_jpg_40.jpg
# 83 Cardinal_0051_17223_jpg_41.jpg
# 85 Western_Meadowlark_0083_78197_jpg_43.jpg
# 87 Cardinal_0075_17946_jpg_45.jpg
# 88 Western_Meadowlark_0115_77882_jpg_46.jpg
# 89 Black_Footed_Albatross_0051_796103_jpg_47.jpg
# 90 Western_Meadowlark_0040_77823_jpg_48.jpg
# 91 Cardinal_0055_18898_jpg_49.jpg
# 92 Cardinal_0075_17946_jpg_50.jpg
# 93 Western_Meadowlark_0115_77882_jpg_51.jpg
# 94 Cardinal_0075_17946_jpg_52.jpg
# 95 Cardinal_0089_18005_jpg_53.jpg
# 96 Western_Meadowlark_0112_78760_jpg_54.jpg
# 97 Cardinal_0089_18005_jpg_55.jpg
# 98 Black_Footed_Albatross_0002_55_jpg_56.jpg
# 99 Cardinal_0081_17291_jpg_57.jpg
# 100 Cardinal_0052_18334_jpg_58.jpg
# 102 Western_Meadowlark_0085_77745_jpg_60.jpg
# 103 Black_Footed_Albatross_0042_796071_jpg_61.jpg
# 104 Black_Footed_Albatross_0061_796082_jpg_62.jpg
# 105 Cardinal_0053_17541_jpg_63.jpg
# 106 Cardinal_0056_18352_jpg_64.jpg
# 107 Western_Meadowlark_0086_78636_jpg_65.jpg
# 108 Western_Meadowlark_0081_77798_jpg_66.jpg
# 109 Cardinal_0052_18334_jpg_67.jpg
# 110 Black_Footed_Albatross_0076_417_jpg_68.jpg
# 111 Western_Meadowlark_0108_78155_jpg_69.jpg
# 112 Cardinal_0081_17291_jpg_70.jpg
# 113 Cardinal_0085_19162_jpg_71.jpg
# 114 Cardinal_0092_17591_jpg_72.jpg
# 115 Western_Meadowlark_0083_78197_jpg_73.jpg
# 116 Western_Meadowlark_0116_77862_jpg_74.jpg
# 117 Black_Footed_Albatross_0076_417_jpg_75.jpg
# 119 Western_Meadowlark_0081_77798_jpg_77.jpg
# 121 Western_Meadowlark_0081_77798_jpg_79.jpg
# 122 Western_Meadowlark_0083_78197_jpg_80.jpg
# 124 Western_Meadowlark_0091_78576_jpg_82.jpg
# 125 Western_Meadowlark_0085_77745_jpg_83.jpg
# 126 Cardinal_0078_17181_jpg_84.jpg
# 127 Western_Meadowlark_0112_78760_jpg_85.jpg
# 129 Cardinal_0054_19334_jpg_87.jpg
# 130 Cardinal_0089_18005_jpg_88.jpg
# 132 Cardinal_0052_18334_jpg_90.jpg
# 133 Western_Meadowlark_0085_77745_jpg_91.jpg
# 134 Black_Footed_Albatross_0081_426_jpg_92.jpg
# 135 Black_Footed_Albatross_0056_796078_jpg_93.jpg
# 137 Western_Meadowlark_0048_78354_jpg_95.jpg
# 138 Western_Meadowlark_0042_78180_jpg_96.jpg
# 139 Western_Meadowlark_0042_78180_jpg_97.jpg
# 141 Western_Meadowlark_0085_77745_jpg_99.jpg
# 142 Cardinal_0055_18898_jpg_100.jpg
# 143 Cardinal_0085_19162_jpg_101.jpg
# 144 Black_Footed_Albatross_0076_417_jpg_102.jpg
# 145 Black_Footed_Albatross_0002_55_jpg_103.jpg
# 146 Black_Footed_Albatross_0051_796103_jpg_104.jpg
# 147 Black_Footed_Albatross_0081_426_jpg_105.jpg
# 148 Cardinal_0051_17223_jpg_106.jpg
# 149 Western_Meadowlark_0040_77823_jpg_107.jpg
# 150 Cardinal_0092_17591_jpg_108.jpg
# 151 Western_Meadowlark_0042_78180_jpg_109.jpg
# 152 Black_Footed_Albatross_0060_796076_jpg_110.jpg
# 153 Western_Meadowlark_0109_77990_jpg_111.jpg
# 154 Western_Meadowlark_0109_77990_jpg_112.jpg
# 155 Western_Meadowlark_0120_77834_jpg_113.jpg
# 156 Western_Meadowlark_0116_77862_jpg_114.jpg
# 157 Black_Footed_Albatross_0076_417_jpg_115.jpg
# 158 Western_Meadowlark_0040_77823_jpg_116.jpg
# 159 Western_Meadowlark_0109_77990_jpg_117.jpg
# 160 Cardinal_0078_17181_jpg_118.jpg
# 161 Black_Footed_Albatross_0061_796082_jpg_119.jpg
# 162 Cardinal_0092_17591_jpg_120.jpg
# 164 Cardinal_0093_17676_jpg_122.jpg
# 165 Cardinal_0054_19334_jpg_123.jpg
# 166 Cardinal_0092_17591_jpg_124.jpg
# 167 Western_Meadowlark_0112_78760_jpg_125.jpg
# 168 Western_Meadowlark_0085_77745_jpg_126.jpg
# 169 Black_Footed_Albatross_0076_417_jpg_127.jpg
# 170 Cardinal_0078_17181_jpg_128.jpg
# 171 Western_Meadowlark_0108_78155_jpg_129.jpg
# 172 Black_Footed_Albatross_0081_426_jpg_130.jpg
# 173 Western_Meadowlark_0091_78576_jpg_131.jpg
# 174 Western_Meadowlark_0115_77882_jpg_132.jpg
# 175 Western_Meadowlark_0120_77834_jpg_133.jpg
# 176 Black_Footed_Albatross_0056_796078_jpg_134.jpg
# 177 Cardinal_0053_17541_jpg_135.jpg
# 178 Western_Meadowlark_0112_78760_jpg_136.jpg
# 179 Black_Footed_Albatross_0056_796078_jpg_137.jpg
# 181 Western_Meadowlark_0040_77823_jpg_139.jpg
# 182 Western_Meadowlark_0108_78155_jpg_140.jpg
# 183 Cardinal_0054_19334_jpg_141.jpg
# 184 Western_Meadowlark_0048_78354_jpg_142.jpg
# 185 Western_Meadowlark_0120_77834_jpg_143.jpg
# 186 Cardinal_0056_18352_jpg_144.jpg
# 187 Western_Meadowlark_0042_78180_jpg_145.jpg
# 188 Black_Footed_Albatross_0060_796076_jpg_146.jpg
# 189 Cardinal_0079_19044_jpg_147.jpg
# 190 Cardinal_0055_18898_jpg_148.jpg
# 191 Black_Footed_Albatross_0061_796082_jpg_149.jpg
# 192 Western_Meadowlark_0120_77834_jpg_150.jpg
# 194 Western_Meadowlark_0081_77798_jpg_152.jpg
# 195 Black_Footed_Albatross_0060_796076_jpg_153.jpg
# 196 Western_Meadowlark_0086_78636_jpg_154.jpg
# 197 Black_Footed_Albatross_0081_426_jpg_155.jpg
# 199 Western_Meadowlark_0116_77862_jpg_157.jpg
# 200 Western_Meadowlark_0083_78197_jpg_158.jpg
# 203 Cardinal_0053_17541_jpg_161.jpg
# 204 Cardinal_0078_17181_jpg_162.jpg
# 205 Western_Meadowlark_0108_78155_jpg_163.jpg
# 206 Cardinal_0075_17946_jpg_164.jpg
# 207 Black_Footed_Albatross_0002_55_jpg_165.jpg
# 208 Cardinal_0085_19162_jpg_166.jpg
# 209 Western_Meadowlark_0086_78636_jpg_167.jpg
# 210 Western_Meadowlark_0115_77882_jpg_168.jpg
# 211 Cardinal_0089_18005_jpg_169.jpg
# 212 Cardinal_0089_18005_jpg_170.jpg
# 213 Cardinal_0055_18898_jpg_171.jpg
# 214 Cardinal_0079_19044_jpg_172.jpg
# 215 Black_Footed_Albatross_0002_55_jpg_173.jpg
# 216 Cardinal_0053_17541_jpg_174.jpg
# 217 Cardinal_0089_18005_jpg_175.jpg
# 218 Western_Meadowlark_0042_78180_jpg_176.jpg
# 219 Western_Meadowlark_0086_78636_jpg_177.jpg
# 220 Cardinal_0092_17591_jpg_178.jpg
# 221 Cardinal_0085_19162_jpg_179.jpg
# 222 Cardinal_0051_17223_jpg_180.jpg
# 223 Western_Meadowlark_0086_78636_jpg_181.jpg
# 224 Cardinal_0052_18334_jpg_182.jpg
# 225 Cardinal_0078_17181_jpg_183.jpg
# 227 Cardinal_0054_19334_jpg_185.jpg
# 228 Black_Footed_Albatross_0051_796103_jpg_186.jpg
# 229 Cardinal_0081_17291_jpg_187.jpg
# 230 Cardinal_0093_17676_jpg_188.jpg
# 232 Black_Footed_Albatross_0056_796078_jpg_190.jpg
# 234 Black_Footed_Albatross_0051_796103_jpg_192.jpg
# 235 Cardinal_0051_17223_jpg_193.jpg
# 236 Cardinal_0085_19162_jpg_194.jpg
# 237 Cardinal_0056_18352_jpg_195.jpg
# 238 Black_Footed_Albatross_0060_796076_jpg_196.jpg
# 239 Black_Footed_Albatross_0042_796071_jpg_197.jpg
# 240 Cardinal_0081_17291_jpg_198.jpg
# 241 Cardinal_0093_17676_jpg_199.jpg
# 242 Cardinal_0085_19162_jpg_200.jpg
# 244 Western_Meadowlark_0042_78180_jpg_202.jpg
# 245 Western_Meadowlark_0115_77882_jpg_203.jpg
# 246 Western_Meadowlark_0091_78576_jpg_204.jpg
# 249 Cardinal_0051_17223_jpg_207.jpg
# 251 Black_Footed_Albatross_0076_417_jpg_209.jpg
# 252 Black_Footed_Albatross_0060_796076_jpg_210.jpg
# 253 Cardinal_0092_17591_jpg_211.jpg
# 254 Western_Meadowlark_0109_77990_jpg_212.jpg
# 255 Black_Footed_Albatross_0042_796071_jpg_213.jpg
# 256 Cardinal_0053_17541_jpg_214.jpg
# 257 Cardinal_0093_17676_jpg_215.jpg
# 258 Western_Meadowlark_0108_78155_jpg_216.jpg
# 259 Western_Meadowlark_0116_77862_jpg_217.jpg
# 260 Black_Footed_Albatross_0061_796082_jpg_218.jpg
# 261 Cardinal_0081_17291_jpg_219.jpg
# 262 Western_Meadowlark_0083_78197_jpg_220.jpg
# 263 Cardinal_0056_18352_jpg_221.jpg
# 264 Western_Meadowlark_0120_77834_jpg_222.jpg
# 265 Cardinal_0052_18334_jpg_223.jpg
# 267 Western_Meadowlark_0109_77990_jpg_225.jpg
# 268 Western_Meadowlark_0116_77862_jpg_226.jpg
# 269 Western_Meadowlark_0081_77798_jpg_227.jpg
# 270 Western_Meadowlark_0120_77834_jpg_228.jpg
# 271 Cardinal_0055_18898_jpg_229.jpg
# 272 Western_Meadowlark_0091_78576_jpg_230.jpg
# 274 Cardinal_0056_18352_jpg_232.jpg
# 276 Western_Meadowlark_0048_78354_jpg_234.jpg
# 277 Western_Meadowlark_0115_77882_jpg_235.jpg
# 278 Western_Meadowlark_0083_78197_jpg_236.jpg
# 279 Black_Footed_Albatross_0061_796082_jpg_237.jpg
# 280 Cardinal_0055_18898_jpg_238.jpg
# 281 Black_Footed_Albatross_0081_426_jpg_239.jpg
# 283 Western_Meadowlark_0048_78354_jpg_241.jpg
# 284 Cardinal_0079_19044_jpg_242.jpg
# 285 Black_Footed_Albatross_0042_796071_jpg_243.jpg
# 286 Black_Footed_Albatross_0056_796078_jpg_244.jpg
# 287 Western_Meadowlark_0108_78155_jpg_245.jpg

# %%
test_images=[]
test_labels=[]

# %%
for i,item in enumerate(test1['filename']):


    box1={}
    box1['x1']=round(float(test1['x1'][i]))
    box1['x2']=round(float(test1['x2'][i]))
    box1['y1']=round(float(test1['y1'][i]))
    box1['y2']=round(float(test1['y2'][i]))
        
        
        
    image = cv2.imread('.'+test1['root'][i]+test1['filename'][i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    imout=image.copy()
    if 'Western' in test1['filename'][i]:
        print(i,item)
        timage=imout[box1['y1']:box1['y2'],box1['x1']:box1['x2']]
        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
        test_images.append(resized)
        test_labels.append(1)
    if 'Black' in test1['filename'][i]:
        print(i,item)
        timage=imout[box1['y1']:box1['y2'],box1['x1']:box1['x2']]
        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
        test_images.append(resized)
        test_labels.append(2)
    if 'Cardinal' in test1['filename'][i]:
        print(i,item)
        timage=imout[box1['y1']:box1['y2'],box1['x1']:box1['x2']]
        resized=cv2.resize(timage,(224,224),interpolation=cv2.INTER_AREA)
        test_images.append(resized)
        test_labels.append(3)
    else:
        continue
# Out:
# 0 Black_Footed_Albatross_0033_796086.jpg
# 1 Black_Footed_Albatross_0038_212.jpg
# 2 Black_Footed_Albatross_0039_796132.jpg
# 3 Black_Footed_Albatross_0057_796106.jpg
# 4 Black_Footed_Albatross_0063_796141.jpg
# 5 Black_Footed_Albatross_0069_796139.jpg
# 6 Black_Footed_Albatross_0090_796077.jpg
# 7 Cardinal_0002_18424.jpg
# 8 Cardinal_0006_17684.jpg
# 9 Cardinal_0033_19215.jpg
# 10 Cardinal_0040_17477.jpg
# 11 Cardinal_0057_17128.jpg
# 12 Cardinal_0060_17139.jpg
# 13 Cardinal_0083_18042.jpg
# 14 Cardinal_0084_17576.jpg
# 15 Cardinal_0104_17122.jpg
# 16 Western_Meadowlark_0044_77758.jpg
# 17 Western_Meadowlark_0050_77864.jpg
# 18 Western_Meadowlark_0053_77774.jpg
# 19 Western_Meadowlark_0076_77811.jpg
# 20 Western_Meadowlark_0077_77814.jpg
# 21 Western_Meadowlark_0095_78568.jpg
# 22 Western_Meadowlark_0103_78500.jpg
# 23 Western_Meadowlark_0104_78105.jpg
# 24 Western_Meadowlark_0107_78608.jpg

# %%
X_train=np.array(train_images)

y_train=np.array(train_labels)
X_test=np.array(test_images)
y_test=np.array(test_labels)

# %%
X_train.shape
# Out:
# (252, 224, 224, 3)

# %%
X_test.shape
# Out:
# (25, 224, 224, 3)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oh=OneHotEncoder(sparse=False,dtype=int,categories='auto')
y_train=oh.fit_transform(y_train.reshape(-1,1))
y_test=oh.transform(y_test.reshape(-1,1))

# %%
cnn1 = Sequential()
#cnn1.add(ZeroPadding2D((1,1),input_shape=(224,224,3)))
cnn1.add(Conv2D(32, (3, 3),input_shape=(224,224,3), activation='relu'))
#cnn1.add(ZeroPadding2D((1,1)))
cnn1.add(Conv2D(32, (3, 3), activation='relu'))
cnn1.add(MaxPooling2D((2,2), strides=(2,2)))
#cnn1.add(ZeroPadding2D((1,1)))
cnn1.add(Conv2D(64, (3, 3), activation='relu'))
#cnn1.add(ZeroPadding2D((1,1)))
cnn1.add(Conv2D(64, (3, 3), activation='relu'))
# cnn1.add(ZeroPadding2D((1,1)))
# cnn1.add(Conv2D(256, (3, 3), activation='relu'))
cnn1.add(MaxPooling2D((2,2), strides=(2,2)))
#cnn1.add(ZeroPadding2D((1,1)))
cnn1.add(Conv2D(128, (3, 3), activation='relu'))
#cnn1.add(ZeroPadding2D((1,1)))
cnn1.add(Conv2D(128, (3, 3), activation='relu'))
cnn1.add(MaxPooling2D((2,2), strides=(2,2)))
cnn1.add(Flatten())
cnn1.add(Dense(256, activation='relu'))
cnn1.add(Dropout(0.2))
cnn1.add(Dense(128, activation='relu'))
cnn1.add(Dropout(0.2))
#cnn1.add(Dense(500, activation='softmax'))
cnn1.add(Dense(3,activation='softmax'))

# %%
cnn1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#early_stop=EarlyStopping(monitor='val_accuracy',min_delta=0,patience=5,verbose=1,mode='auto')
history = cnn1.fit(X_train,
                        y_train,
                        batch_size=32,
                        validation_data=(X_test, y_test),
                        epochs=20,
                        verbose=1)
# Out:
# Train on 252 samples, validate on 25 samples
# Epoch 1/20
# 252/252 [==============================] - 6s 24ms/sample - loss: 76.2967 - accuracy: 0.3730 - val_loss: 2.0168 - val_accuracy: 0.4000
# Epoch 2/20
# 252/252 [==============================] - 2s 9ms/sample - loss: 2.4779 - accuracy: 0.4683 - val_loss: 0.7826 - val_accuracy: 0.4400
# Epoch 3/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.6676 - accuracy: 0.6706 - val_loss: 0.5428 - val_accuracy: 0.7200
# Epoch 4/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.5485 - accuracy: 0.7738 - val_loss: 0.4721 - val_accuracy: 0.8000
# Epoch 5/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.3733 - accuracy: 0.8452 - val_loss: 0.4349 - val_accuracy: 0.8000
# Epoch 6/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.3385 - accuracy: 0.9603 - val_loss: 0.3528 - val_accuracy: 0.9600
# Epoch 7/20
# 252/252 [==============================] - 2s 9ms/sample - loss: 0.2635 - accuracy: 0.9683 - val_loss: 0.3322 - val_accuracy: 0.8400
# Epoch 8/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.2331 - accuracy: 0.9405 - val_loss: 0.1477 - val_accuracy: 1.0000
# Epoch 9/20
# 252/252 [==============================] - 2s 9ms/sample - loss: 0.0917 - accuracy: 0.9841 - val_loss: 0.1427 - val_accuracy: 0.8800
# Epoch 10/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.1053 - accuracy: 0.9881 - val_loss: 0.2546 - val_accuracy: 0.8800
# Epoch 11/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.4676 - accuracy: 0.9286 - val_loss: 0.4011 - val_accuracy: 0.9600
# Epoch 12/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.2882 - accuracy: 0.9643 - val_loss: 0.3821 - val_accuracy: 0.7600
# Epoch 13/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.2538 - accuracy: 0.9167 - val_loss: 0.2997 - val_accuracy: 0.9600
# Epoch 14/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.2474 - accuracy: 0.9722 - val_loss: 0.3352 - val_accuracy: 0.9600
# Epoch 15/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.1866 - accuracy: 0.9563 - val_loss: 0.1936 - val_accuracy: 1.0000
# Epoch 16/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.1365 - accuracy: 0.9841 - val_loss: 0.3204 - val_accuracy: 0.9200
# Epoch 17/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.2540 - accuracy: 0.9722 - val_loss: 0.2131 - val_accuracy: 0.8800
# Epoch 18/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.1720 - accuracy: 0.9405 - val_loss: 0.1860 - val_accuracy: 1.0000
# Epoch 19/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.1024 - accuracy: 0.9762 - val_loss: 0.2461 - val_accuracy: 0.8400
# Epoch 20/20
# 252/252 [==============================] - 2s 8ms/sample - loss: 0.1653 - accuracy: 0.9722 - val_loss: 0.1960 - val_accuracy: 1.0000

# %%
plt.imshow(X_test[13])

# %%
X_test[19].shape
# Out:
# (224, 224, 3)

# %%
cnn1.predict(np.reshape(X_test[13],(1,224,224,3)))
# Out:
# array([[1.0966607e-30, 0.0000000e+00, 1.0000000e+00]], dtype=float32)

# %% [markdown]
# 1=Western Meadowlark, 2=RedWing Blackbird 3=Cardinal
